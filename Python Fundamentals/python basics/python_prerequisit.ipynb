# %% [markdown]
# # Python Requirements

# %% [markdown]
# ## We are going to cover the python requirements

# %%
print("Hello World !!!")
# Out:
# Hello World !!!

# %%
name = "Amit"
Name = "Amit"
name == Name
# Out:
# True

# %%
name = "Amit"
Name = "amit"
name == Name
# Out:
# False
