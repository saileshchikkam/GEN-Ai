# %% [markdown]
# # Data Types

# %%
age = input("Enter your age: ")
print(age)
print(type(age)) # we print the type of age variable which is str
# Out:
# 19
# <class 'str'>

# %%
age2 = 13
combined_age = age + str(age2) # we convert the integer value of age2 to string and combine it with the string value of age
print(combined_age)
# Out:
# 1913

# %% [markdown]
# # Different types of data types

# %% [markdown]
# 1. str
# 2. float
# 3. boolean
# 4. int

# %%
a = 7
b = 7
# a==b it is also an example of boolean
is_true = a == b 
print(is_true)
# Out:
# True
