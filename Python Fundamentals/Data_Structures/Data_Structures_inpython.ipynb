# %% [markdown]
# # Data Sturctures in Python

# %% [markdown]
# #### Stores the data in a structured format so that we can access the data and along with that operations like (Create,Read,Update,Delete) operations

# %% [markdown]
# ## Types of data structures in python are:
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# ## The different types of data structure differes on this basis that in which specific format we want to store our data
