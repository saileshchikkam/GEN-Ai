# %% [markdown]
# # Modules and Packages

# %%
def addition(num1,num2):
    return num1 + num2

# %%
addition(2,3)
# Out:
# 5

# %% [markdown]
# ### I want use this logic of the function in this file into the other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# ## MODULE
#
# ### Module in python is simply a file containing python vode that is functions classes and variables that can be imported and used in other programmes

# %% [markdown]
# ### Numpy ---->  numpy is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the list

# %% [markdown]
# ### ---> We can do it in numpy just beacuse numpy is having the collection of functions and attributes which can help us to work efficiently with the array

# %% [markdown]
# ### Pandas
#
# #### Pandas we can use when we are going to work with the dataset for cleaning , preprocessing, EDA, analysis with plotting as well

# %%
import math
math.sqrt(24)
# Out:
# 4.898979485566356

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
pi
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## A Module:
#
# ### 1. A module helps in code organization
# ### 2. It promotes reusability
# ### 3. It keep the code clean and managable as well

# %%
cos(0)
# Out:
# 1.0

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy

# %%
list_items = [1,2,3,4]
numpy_array = numpy.array(list_items)
print(numpy_array)
# Out:
# [1 2 3 4]

# %%
print(type(numpy_array))
# Out:
# <class 'numpy.ndarray'>

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting seaborn
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.3 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 7.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.3 MB 8.2 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.3 MB 8.1 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 8.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.8/2.3 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 8.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
# ...

# %% [markdown]
# ### --> I am trying to create my own library, in this library i want the functions and the attributes to be created on my own

# %% [markdown]
# ## __init__.py is a file that has to there inside the package folder, this file going to help us out indefining oour packages and also initializing our name spaces as well
#
# ## this __init__ file can be empty also,  it completly fine but this file has to be there in creating out new packages into the packages folder

# %%
from Package_Folder.mathematics import *
addition(4,8)
# Out:
# 12

# %%
subtraction(99,100)
# Out:
# 1

# %%
multiplication(9,0)
# Out:
# 0

# %% [markdown]
# ### to call this package inside a .py file then
# ### cd python file_name.py

# %%
from Package_Folder.subpackage.sum import *
addition(1,2,3,4)
# Out:
# 10
