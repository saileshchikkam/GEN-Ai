# %% [markdown]
# # Exception Handling

# %%
denominator = int(input("Please enter the denominator for division"))

result = 1/denominator

print(result)
# Out:
# -1.0

# %% [markdown]
# ## Def : Exception Handling is the way in which if we are getting the errors in programming or if the user entered input causes an error then instead of throwing an error we can rise an exception

# %% [markdown]
# ### --> we will learn how to handle the errors

# %%
denominator = int(input("Please enter the denominator for division"))

if denominator == 0:
    print("Denominator value '0' is not allowed")
else:
    result = 1/denominator
    print(result)
# Out:
# Denominator value '0' is not allowed

# %%
denominator = int(input("Please enter the denominator for division"))

if denominator == 0:
    print("Denominator value '0' is not allowed")
else:
    result = 1/denominator
    print(result)

calculation = denominator + 5
print(calculation)
# Out:
# Denominator value '0' is not allowed
# 5

# %% [markdown]
# ### ---> We don't want to stop execution of the program, so we rise an error thet current input is not correct but program execution won't stop

# %% [markdown]
# ## Different types of exception
#
# ### 1. ZeroDivision Error
# ### 2. File Not Found Error
# ### 3. Value Error
# ### 4. Type Error

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a= b
#
# NameError: name 'b' is not defined

# %% [markdown]
# ## Exception Handling completly depends on
# ## try Except Block

# %% [markdown]
# #### try    :
# ####    result = a/b
#
# #### except:
# ####    print("The division is not valid")

# %%
try:
    a=b
except:
    print("Value b is not assigned")
# Out:
# Value b is not assigned

# %%
try:
    a=b
except NameError as exception:
    print(exception)
# Out:
# name 'b' is not defined

# %%
den = int(input("Enter denominator value: "))
try:
    result = 1/den
    print(result)
except ZeroDivisionError as exception:
    print(exception)
# Out:
# division by zero

# %%
b = input("Enter deno: ")

try:
    result = 1/b
    print(result)
    m = n
    
except ZeroDivisionError as ex1:
    print(ex1)
except NameError as ex2:
    print(ex2)
except Exception as ex3:
    print(ex3)
    # primary Exception class must be mentioned at the end only
# Out:
# unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# ### --> If we are getting an error and we are not aware that which specific error type it is then we can use the primary exception class which is Execption
#
# ### --> The parent Exception type must be mentioned at the end or Last as it is the Parent class so only if the previous exception class will not catch the error then this final one will be able to catch it
#
# ### ** try --> try block is going to have the operation where we can except an error to occur
#
# ### ** except --> to handle the error in a way such that the program execution doesn't stop
#
# ### ** else
# ### if the try block code is throwing an error --> except ---> code will be running ot if try ---> code is not throwing an Error ---> Else ---> code will be running
#
# ### ** finally --> finally block gets executed once we are done with Everything and even if we are getting an error or not still the code inside the finally block gets executed

# %%
num = int(input("Enter the Denominator value: "))
try:
    result = 1/num
except Exception as ex:
    print(ex)
else:
    print("The division result is: ",result)
# Out:
# The division result is:  0.2

# %% [markdown]
# ### Set up a Database
#
# ## try:
#         Code to setup the database
#
# ## except :
#
# ## else:
#         Further code that what exactly should happened once we are done with successfully setting up the database
#
# ## finally:
#         print("You are successfully done with setting up the database")

# %%
try:
    den = int(input("Enter the denominator value: "))
    result = 1/den

    a=b

    den2 = input("Enter the second denominator")
    result2 = 1/den2
except ZeroDivisionError as ex1:
    print(ex1)
except NameError as ex2:
    print(result)
except Exception as ex:
    print(ex)
else:
    print("The division of 1 is: ",result)
    print("The division of 1 is: ",result2)
finally:
    print("Progarmme execution is done now")
# Out:
# unsupported operand type(s) for /: 'int' and 'str'
# Progarmme execution is done now

# %% [markdown]
# ## File Not Found Error

# %%
try:
    f = open('example.txt','r')
    content = f.read()
    print(content)
except FileNotFoundError as ex:
    print(ex)
finally:
    if 'f' in locals() and not file.closed():
        f.close()
        print('file closed')
# Out:
# [Errno 2] No such file or directory: 'example.txt'
