# %% [markdown]
# ## Data Gathering

# %%
## import all required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
import sklearn

# %% [markdown]
# ### Data Gathering

# %%
df = pd.read_csv('International_Education_Costs.csv')

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
df.shape
# Out:
# (907, 12)

# %%
df.tail()
# Out:
#           Country        City                University               Program  \
# 902        France  Strasbourg  University of Strasbourg        Data Analytics
# 903      Malaysia       Nilai                      USIM      Computer Science
# 904  Saudi Arabia     Al-Ahsa    King Faisal University   Information Systems
# 905           USA     Seattle  University of Washington  Software Development
# 906            UK  Nottingham  University of Nottingham      Data Engineering
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 902    Master             2.0         4000               70.2      1000
# 903  Bachelor             3.0         6800               50.5       400
# 904    Master             2.0         4200               64.2       600
# 905       PhD             5.0        50000               77.8      2000
# 906    Master             2.0        34000               61.2       800
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# ...

# %%
df.sample()
# Out:
#     Country            City                 University           Program  \
# 268      UK  Royal Holloway  Royal Holloway University  Computer Science
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 268  Bachelor             3.0        23200               75.5      1400
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 268           490            800           0.79

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 85.2 KB

# %%
df.shape
# Out:
# (907, 12)

# %%
df.size
# Out:
# 10884

# %%
df.dtypes ## float64 can be changed to float32
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Country'].value_counts()  # 71 countries
# Out:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Taiwan             1
# Czech Republic     1
# South Africa       1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64

# %%
df['Country'].unique()  # 71 countries
# Out:
# <StringArray>
# [               'USA',                 'UK',             'Canada',
#           'Australia',            'Germany',              'Japan',
#         'Netherlands',          'Singapore',             'France',
#         'Switzerland',             'Sweden',            'Denmark',
#               'China',        'South Korea',            'Ireland',
#         'New Zealand',            'Austria',            'Belgium',
#           'Hong Kong',           'Portugal',             'Israel',
#              'Taiwan',     'Czech Republic',              'India',
#              'Poland',           'Malaysia',              'Spain',
#               'Italy',            'Finland',             'Norway',
#              'Brazil',             'Turkey',             'Russia',
#              'Mexico',             'Greece',           'Thailand',
#                 'UAE',       'South Africa',              'Egypt',
#           'Argentina',          'Indonesia',       'Saudi Arabia',
# ...

# %%
df[df['Country'] == 'India']
# Out:
#     Country       City                   University                  Program  \
# 44    India  Bangalore  Indian Institute of Science         Computer Science
# 648   India  Bangalore  Indian Institute of Science             Data Science
# 654   India     Mumbai                   IIT Bombay     Computer Engineering
# 659   India      Delhi                    IIT Delhi  Artificial Intelligence
# 665   India    Chennai                   IIT Madras     Software Engineering
# 671   India  Hyderabad                IIT Hyderabad           Data Analytics
# 677   India       Pune                     IIT Pune         Computer Science
# 683   India     Kanpur                   IIT Kanpur  Artificial Intelligence
#
#       Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 44   Master             2.0         2500               45.6       500
# 648     PhD             4.0         2000               45.2       300
# ...

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
df['City'].value_counts()  # 71 countries
# Out:
# City
# Singapore    18
# Melbourne    11
# Sydney       11
# London       10
# Canberra      8
#              ..
# Tabuk         1
# Shah Alam     1
# Makkah        1
# Nilai         1
# Al-Ahsa       1
# Name: count, Length: 556, dtype: int64

# %%
df['City'].unique()
# Out:
# <StringArray>
# ['Cambridge',    'London',   'Toronto', 'Melbourne',    'Munich',     'Tokyo',
#  'Amsterdam', 'Singapore',     'Paris',    'Zurich',
#  ...
#  'Cyberjaya',    'Dammam',     'Bangi',      'Taif',    'Melaka',     'Tabuk',
#  'Shah Alam',    'Makkah',     'Nilai',   'Al-Ahsa']
# Length: 556, dtype: str

# %%
df['Program'].value_counts()  # 71 countries
# Out:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64

# %%
df['Level'].value_counts()  # 71 countries
# Out:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
df['Duration_Years'].min()
# Out:
# np.float64(1.0)

# %%
df['Duration_Years'].max()
# Out:
# np.float64(5.0)

# %%
df['Duration_Years'].mean()
# Out:
# np.float64(2.8368246968026463)

# %% [markdown]
# ### Data Cleaning

# %%
## isnull() function is used to find the missing values in the dataset. It returns a boolean value indicating whether each element is null or not.
df.isnull().sum() ## there is no null values in the dataset. So, we don't need to handle missing values.
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
df.duplicated().sum() ## there is no duplicate values in the dataset. So, we don't need to handle duplicate values.
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
## astype() function is used to convert the data type of a column in a DataFrame. It takes the desired data type as an argument and returns a new DataFrame with the specified column converted to that data type.
df['Duration_Years'] = df['Duration_Years'].astype('float32')
df['Rent_USD'] = df['Rent_USD'].astype('float32')
df['Tuition_USD'] = df['Tuition_USD'].astype('int32')
df['Visa_Fee_USD'] = df['Visa_Fee_USD'].astype('int32')
df['Insurance_USD'] = df['Insurance_USD'].astype('int32')

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float32
# Tuition_USD            int32
# Living_Cost_Index    float64
# Rent_USD             float32
# Visa_Fee_USD           int32
# Insurance_USD          int32
# Exchange_Rate        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    float32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float32(2), float64(2), int32(3), str(5)
# memory usage: 67.4 KB

# %% [markdown]
# ### EDA Exploratory Data Analysis

# %%
## Univariate Analysis

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# UK             93
# Australia      86
# USA            78
# Canada         76
# Germany        33
# France         27
# South Korea    23
# Netherlands    21
# Switzerland    20
# Singapore      18
# Name: count, dtype: int64

# %%
country = df[df['Country'].isin(['USA', 'UK', 'Canada', 'Australia', 'Germany', 'France', 'South Korea','Netherlands', 'Switzerland', 'Singapore'])]

# %%
sns.countplot(x='Country', data=country) ## labels overlaped
plt.xticks(rotation='vertical')
plt.show()

# %%
df['City'].value_counts().head()
# Out:
# City
# Singapore    18
# Melbourne    11
# Sydney       11
# London       10
# Canberra      8
# Name: count, dtype: int64

# %%
city = df[df['City'].isin(['London', 'Sydney','Singapore','Melbourne','Canberra'])]

# %%
city.shape
# Out:
# (58, 12)

# %%
sns.countplot(x='Level', data=df)
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %%
d1 = df[df['Level'] == 'Master'].head(150)
d2 = df[df['Level'] == 'Bachelor'].head(150)
d3 = df[df['Level'] == 'PhD'].head(150)

# %%
d1.shape
# Out:
# (150, 12)

# %%
d2.shape
# Out:
# (150, 12)

# %%
d3.shape
# Out:
# (150, 12)

# %%
## concatenate the three dataframes into a single dataframe
d4 = pd.concat([d1, d2, d3], axis=0)

# %%
d4.shape ## concatenated
# Out:
# (450, 12)

# %%
df.shape
# Out:
# (907, 12)

# %%
## df dataframe
sns.histplot(data = df, x = 'Duration_Years')
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Count'>

# %%
## d4 dataframe ---> 150 each of Level
sns.histplot(data = d4, x = 'Duration_Years')
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
sns.histplot(data=df,x='Tuition_USD')
# Out:
# <Axes: xlabel='Tuition_USD', ylabel='Count'>

# %%
sns.histplot(data = df,x = 'Rent_USD')
# Out:
# <Axes: xlabel='Rent_USD', ylabel='Count'>

# %%
sns.kdeplot(data = df, x= 'Rent_USD')
plt.grid()

# %%
sns.boxplot(data = df, x= 'Rent_USD')
# Out:
# <Axes: xlabel='Rent_USD'>

# %%
## bivariante Analysis

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    float32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float32(2), float64(2), int32(3), str(5)
# memory usage: 67.4 KB

# %%
## Tuition fee for the top 10 countries
sns.barplot(data = country, x = 'Country', y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
country.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5    2200.0           160           1500           1.00
# 1               75.8    1800.0           485            800           0.79
# ...

# %%
## Visa_Fee Country wise ## bivariate analysis
sns.barplot(data = country, x = 'Country', y = 'Visa_Fee_USD')
plt.xticks(rotation=45)
plt.show()

# %%
df['University'].value_counts().head(10)
# Out:
# University
# University of Washington           6
# University of Melbourne            5
# Stanford University                5
# Australian National University     5
# University of Sydney               5
# University of Adelaide             5
# University of Western Australia    5
# Griffith University                5
# University of Tasmania             5
# University of Newcastle            5
# Name: count, dtype: int64

# %%
university = df[df['University'].isin(['University of Washington', 'University of Melbourne', 'Stanford University', 'Australian National University', 'University of Sydney', 'University of Adelaide', 'University of Western Australia', 'Griffith University', 'University of Tasmania', 'University of Newcastle'])]

# %%
university.shape
# Out:
# (51, 12)

# %%
sns.barplot(data = university, x = 'University', y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data = university, x = 'University', y = 'Duration_Years')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.lineplot(data = university, x = 'University', y = 'Duration_Years')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
sns.lineplot(data = df, x = 'Duration_Years',y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
sns.scatterplot(data = df, x = 'Duration_Years',y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
## Top 10 countries and  Top 10 Universities Tuition Fees (HeatMap)

# %%
country['Country'].value_counts()
# Out:
# Country
# UK             93
# Australia      86
# USA            78
# Canada         76
# Germany        33
# France         27
# South Korea    23
# Netherlands    21
# Switzerland    20
# Singapore      18
# Name: count, dtype: int64

# %%
country['University'].value_counts().head(10)
# Out:
# University
# University of Washington           6
# University of Melbourne            5
# Stanford University                5
# Australian National University     5
# University of Sydney               5
# University of Adelaide             5
# University of Western Australia    5
# Griffith University                5
# University of Tasmania             5
# University of Newcastle            5
# Name: count, dtype: int64

# %%
university = country[country['University'].isin(['University of Washington', 'University of Melbourne', 'Stanford University', 'Australian National University', 'University of Sydney', 'University of Adelaide', 'University of Western Australia', 'Griffith University', 'University of Tasmania', 'University of Newcastle'])]

# %%
## pivot table ---> filtered tablee

data = university.pivot_table(index='Country', columns='University', values='Tuition_USD', aggfunc='mean')

# %%
sns.heatmap(data)
# Out:
# <Axes: xlabel='University', ylabel='Country'>

# %% [markdown]
# ### Feature Engineering and Model Building

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5    2200.0           160           1500           1.00
# 1               75.8    1800.0           485            800           0.79
# ...

# %%
## addition of Tuition_Fee & Rent_USD
## New output column = Total_Cost_USD
df['Total_Cost_USD'] = df['Tuition_USD'] + df['Rent_USD']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    float32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
#  12  Total_Cost_USD     907 non-null    float64
# dtypes: float32(2), float64(3), int32(3), str(5)
# memory usage: 74.5 KB

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate  \
# 0               83.5    2200.0           160           1500           1.00
# 1               75.8    1800.0           485            800           0.79
# ...

# %%
df['Total_Cost_USD']
# Out:
# 0      57600.0
# 1      43000.0
# 2      40100.0
# 3      43400.0
# 4       1600.0
#         ...
# 902     5000.0
# 903     7200.0
# 904     4800.0
# 905    52000.0
# 906    34800.0
# Name: Total_Cost_USD, Length: 907, dtype: float64

# %%
## Feature Selection ----> Mention all column names inside a list and the list should be inside a dataframe
df = df[['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years', 'Living_Cost_Index', 'Visa_Fee_USD', 'Insurance_USD', 'Total_Cost_USD']]

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Living_Cost_Index  \
# 0        Computer Science  Master             2.0               83.5
# 1            Data Science  Master             1.0               75.8
# 2      Business Analytics  Master             2.0               72.5
# 3             Engineering  Master             2.0               71.2
# 4  Mechanical Engineering  Master             2.0               70.5
#
#    Visa_Fee_USD  Insurance_USD  Total_Cost_USD
# 0           160           1500         57600.0
# 1           485            800         43000.0
# 2           235            900         40100.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Living_Cost_Index  907 non-null    float64
#  7   Visa_Fee_USD       907 non-null    int32
#  8   Insurance_USD      907 non-null    int32
#  9   Total_Cost_USD     907 non-null    float64
# dtypes: float32(1), float64(2), int32(2), str(5)
# memory usage: 60.4 KB

# %%
## Label Encoding ----> Convert Categorical data into Numerical data
## or Feature Encoding ---> we want to feed this data to a mathematical model
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() ## object of LabelEncoder class

# %%
df['Country'] = le.fit_transform(df['Country']) # categorical to numerical

# %%
df.head()
# Out:
#    Country       City                      University                 Program  \
# 0       66  Cambridge              Harvard University        Computer Science
# 1       65     London         Imperial College London            Data Science
# 2        9    Toronto           University of Toronto      Business Analytics
# 3        2  Melbourne         University of Melbourne             Engineering
# 4       22     Munich  Technical University of Munich  Mechanical Engineering
#
#     Level  Duration_Years  Living_Cost_Index  Visa_Fee_USD  Insurance_USD  \
# 0  Master             2.0               83.5           160           1500
# 1  Master             1.0               75.8           485            800
# 2  Master             2.0               72.5           235            900
# 3  Master             2.0               71.2           450            650
# 4  Master             2.0               70.5            75            550
#
#    Total_Cost_USD
# 0         57600.0
# ...

# %%
df['City']=le.fit_transform(df['City'])
df['University']=le.fit_transform(df['University'])
df['Program']=le.fit_transform(df['Program'])
df['Level']=le.fit_transform(df['Level'])

# %%
df.head() ## see everything is numerical 😁
# Out:
#    Country  City  University  Program  Level  Duration_Years  \
# 0       66    84         101       17      1             2.0
# 1       65   283         128       27      1             1.0
# 2        9   503         572        9      1             2.0
# 3        2   313         495       44      1             2.0
# 4       22   330         307       66      1             2.0
#
#    Living_Cost_Index  Visa_Fee_USD  Insurance_USD  Total_Cost_USD
# 0               83.5           160           1500         57600.0
# 1               75.8           485            800         43000.0
# 2               72.5           235            900         40100.0
# 3               71.2           450            650         43400.0
# 4               70.5            75            550          1600.0

# %%
## now we have proper columns lets feed
## Before that lets separete the input and output columns

# %%
x = df.iloc[:, :-1] ## input columns[rows,cols]
y = df['Total_Cost_USD'] ## output column

# %%
x
# Out:
#      Country  City  University  Program  Level  Duration_Years  \
# 0         66    84         101       17      1             2.0
# 1         65   283         128       27      1             1.0
# 2          9   503         572        9      1             2.0
# 3          2   313         495       44      1             2.0
# 4         22   330         307       66      1             2.0
# ..       ...   ...         ...      ...    ...             ...
# 902       21   469         556       25      1             2.0
# 903       38   344         345       17      0             3.0
# 904       51    12         154       57      1             2.0
# 905       66   441         585       84      2             5.0
# 906       65   347         512       26      1             2.0
#
#      Living_Cost_Index  Visa_Fee_USD  Insurance_USD
# 0                 83.5           160           1500
# 1                 75.8           485            800
# ...

# %%
y
# Out:
# 0      57600.0
# 1      43000.0
# 2      40100.0
# 3      43400.0
# 4       1600.0
#         ...
# 902     5000.0
# 903     7200.0
# 904     4800.0
# 905    52000.0
# 906    34800.0
# Name: Total_Cost_USD, Length: 907, dtype: float64

# %%
## Feature Scaling ----> Standardization or Normalization data
from sklearn.preprocessing import StandardScaler

s = StandardScaler()

# %%
s.fit_transform (x) ##inputs 'x'
# Out:
# array([[ 1.29937861, -1.18314994, -1.25623694, ...,  1.35689951,
#         -0.3585248 ,  2.49821139],
#        [ 1.25678296,  0.02539721, -1.10697039, ...,  0.80880148,
#          1.90854833,  0.31206552],
#        [-1.12857335,  1.3614795 ,  1.3476352 , ...,  0.57390232,
#          0.16464592,  0.62437207],
#        ...,
#        [ 0.66044389, -1.62041323, -0.96323222, ..., -0.01690464,
#         -0.07950042,  0.31206552],
#        [ 1.29937861,  0.98494722,  1.41950429, ...,  0.9511646 ,
#         -0.3585248 ,  2.49821139],
#        [ 1.25678296,  0.4140757 ,  1.01593175, ..., -0.23044933,
#          1.90854833,  0.31206552]], shape=(907, 9))

# %%
## no standard scalar for output column 'y' because we are predicting the cost in USD

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train.shape
# Out:
# (725, 9)

# %%
x_test.shape
# Out:
# (182, 9)

# %%
y_train.shape
# Out:
# (725,)

# %%
y_test.shape
# Out:
# (182,)

# %% [markdown]
# ### Model Training and Evaluation

# %%
## now we have proper data now lets feed to the model and train the model
## into the algorithms and see which algorithm is best for our dataset

# %%
## Regression and Classificatiom

# %%
## Regression ---> 1. Linear Regression
##                 2. Ridge Regression
##                 3. Lasso Regression
##                 4. Elastic Net - Regression
##                 5. Decision Tree Regressor
##                 6. Random Forest Regressor
##                 7. XGBoost Regressor
##                 8. AdaBoost Regressor
##                 9. CatBoost Regressor
##                 10. KNeighbour Regressor
##                 11. SVR (Support Vector Regressor)
##                 12. Bagging regressor
##                 13. Stacking regressor

# %%
## Evaluation Metrics --> how correct are the models outputs is?
##                    --> 1. Mean Squared Error (MSE)
##                    --> 2. Root Mean Squared Error (RMSE)
##                    --> 3. Mean Absolute Error (MAE)

# %% [markdown]
# ### Regression

# %% [markdown]
# ### 1. Linear Regressison

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
## fit() ---> To train your machine learning model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
## predict()
y_predict = lr.predict(x_test)

# %%
## Evaluation Metrics
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_predict) ### huge error
# Out:
# 8659.427341273538

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 130433373.64519878

# %% [markdown]
# ### 2. Ridge Regression

# %%
from sklearn.linear_model import Ridge
r = Ridge()

# %%
r.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_predict = r.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 8659.430791591045

# %% [markdown]
# ### 3. Lasso Regression

# %%
from sklearn.linear_model import Lasso
l = Lasso(alpha = 0.1)

# %%
l.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_predict = l.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 8659.412655816815

# %% [markdown]
# ### 4. Elastic Net Algorithm

# %%
from sklearn.linear_model import ElasticNet

e = ElasticNet(alpha=0.01, l1_ratio=0.5)

# %%
e.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.01)

# %%
y_predict = e.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 8659.439321580785

# %% [markdown]
# ### 5. Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(max_depth = 5)

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_predict = tree.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## finally reduced 😅
# Out:
# 4136.742081363999

# %%
## decision tree better than linear regression

# %% [markdown]
# ### 6. Random Forest Regressor
# ### (Ensemble Learning Technique) --->combination of multiple decision trees

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators = 100)

# %%
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict = forest.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## best model across we see
# Out:
# 2634.800183150183

# %% [markdown]
# ### Ensemble Learning --->
# ### 1. XGBoost Regressor
# ### 2. Ada Boost Regressor
# ### 3. Cat Boost Regressor

# %% [markdown]
# ### 7. Ada Boost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada = AdaBoostRegressor(n_estimators = 100)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=100)

# %%
y_predict = ada.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict) ## OK
# Out:
# 5738.694595046422

# %% [markdown]
# ### 8. XG Boost Regressor

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(n_estimators = 100)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict = xgb.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## XGBoost we got best results
# Out:
# 2086.7581218677565

# %% [markdown]
# ### 9. Cat Boost Algorithm

# %%
pip install catboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
from catboost import CatBoostRegressor

# %%
cat = CatBoostRegressor(n_estimators=100)

# %%
cat.fit(x_train,y_train)
# Out:
# Learning rate set to 0.252996
# 0:	learn: 14317.4842791	total: 142ms	remaining: 14s
# 1:	learn: 12451.8189470	total: 146ms	remaining: 7.16s
# 2:	learn: 10837.6169670	total: 153ms	remaining: 4.93s
# 3:	learn: 9347.8058282	total: 158ms	remaining: 3.8s
# 4:	learn: 8353.8578871	total: 163ms	remaining: 3.11s
# 5:	learn: 7550.6326945	total: 168ms	remaining: 2.63s
# 6:	learn: 6926.6977073	total: 173ms	remaining: 2.3s
# 7:	learn: 6486.8579005	total: 177ms	remaining: 2.03s
# 8:	learn: 6068.8307293	total: 181ms	remaining: 1.83s
# 9:	learn: 5796.1440443	total: 183ms	remaining: 1.65s
# 10:	learn: 5467.9974198	total: 186ms	remaining: 1.51s
# 11:	learn: 5212.1054451	total: 189ms	remaining: 1.39s
# 12:	learn: 5133.0999628	total: 191ms	remaining: 1.28s
# 13:	learn: 4967.7737738	total: 193ms	remaining: 1.18s
# 14:	learn: 4886.4254752	total: 195ms	remaining: 1.1s
# 15:	learn: 4820.9000223	total: 196ms	remaining: 1.03s
# 16:	learn: 4762.2294236	total: 198ms	remaining: 965ms
# ...

# %% [markdown]
# ### 10 . KNN Regression ---> Neighbour Data Points --->neighbours predictions ---> closer predictions

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
KNN = KNeighborsRegressor(n_neighbors = 5)

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predict = KNN.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 5767.736263736264

# %% [markdown]
# ### 11. Support Vector Machine (SVR) Regressor

# %%
from sklearn.svm import SVR

# %%
SVR = SVR(kernel = 'rbf')

# %%
SVR.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_predict = SVR.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## very huge
# Out:
# 14304.243421712292

# %% [markdown]
# ### 12. Bagging Regressor ---> Ensemble Learning

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag = BaggingRegressor(n_estimators=100)

# %%
bag.fit(x_train, y_train)
# Out:
# BaggingRegressor(n_estimators=100)

# %%
y_predict = bag.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 2582.828205128205

# %% [markdown]
# ### 13. Stacking Regressor ---> Ensemble learning
# ### ---> Combination of the multiple models of the own choice

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import BaggingRegressor

# %%
estimators = [('rf',RandomForestRegressor()),('br',BaggingRegressor())]

# %%
stack = StackingRegressor(estimators=estimators,final_estimator=DecisionTreeRegressor())

# %%
stack
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor()),
#                               ('br', BaggingRegressor())],
#                   final_estimator=DecisionTreeRegressor())

# %%
stack.fit(x_train,y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor()),
#                               ('br', BaggingRegressor())],
#                   final_estimator=DecisionTreeRegressor())

# %%
y_predict = stack.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## ok
# Out:
# 4595.659340659341

# %% [markdown]
# ## Classification

# %%
### Classification Algorithms ---> 1. Logistic Regression
###                           ---> 2. Decision Tree Classifier
###                           ---> 3. Random Forest Classifier
###                           ---> 4. XGB Classifier
###                           ---> 5. AdaBoost Classifier
###                           ---> 6. CatBoost Classifier
###                           ---> 7. KNeighbour Classifier
###                           ---> 8. Support Vector Classifier
###                           ---> 9. Bernoulli Naive Bayes Classifier
###                           ---> 10.Multinomial Naive Bayes Classifier
###                           ---> 11. Bagging Classifier
###                           ---> 12. Stacking Classifier

# %%
### Classification ---> Evaluation Metrics 
### 1. accuracy - score
### 2. precision
### 3. Recall
### 4. f1-Score
### 5. confusion-matrix

# %%
st = pd.read_csv("Student Depression Dataset.csv")

# %%
st.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %% [markdown]
# ###  Feature Selection

# %%
st.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='str')

# %%
st = st[['Gender', 'Age', 'City', 'Profession', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Sleep Duration', 'Dietary Habits','Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness', 'Depression']]

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
st['Gender'] = le.fit_transform(st['Gender'])

# %%
st.head()
# Out:
#    Gender   Age           City Profession  Academic Pressure  CGPA  \
# 0       1  33.0  Visakhapatnam    Student                5.0  8.97
# 1       0  24.0      Bangalore    Student                2.0  5.90
# 2       1  31.0       Srinagar    Student                3.0  7.03
# 3       0  28.0       Varanasi    Student                3.0  5.59
# 4       0  25.0         Jaipur    Student                4.0  8.13
#
#    Study Satisfaction     Sleep Duration Dietary Habits  Work/Study Hours  \
# 0                 2.0          5-6 hours        Healthy               3.0
# 1                 5.0          5-6 hours       Moderate               3.0
# 2                 5.0  Less than 5 hours        Healthy               9.0
# 3                 2.0          7-8 hours       Moderate               4.0
# 4                 3.0          5-6 hours       Moderate               1.0
#
#    Financial Stress Family History of Mental Illness  Depression
# ...

# %%
st['City'] = le.fit_transform(st['City'])

# %%
st['Profession'] = le.fit_transform(st['Profession'])

# %%
st.head()
# Out:
#    Gender   Age  City  Profession  Academic Pressure  CGPA  \
# 0       1  33.0    51          11                5.0  8.97
# 1       0  24.0     3          11                2.0  5.90
# 2       1  31.0    44          11                3.0  7.03
# 3       0  28.0    49          11                3.0  5.59
# 4       0  25.0    16          11                4.0  8.13
#
#    Study Satisfaction     Sleep Duration Dietary Habits  Work/Study Hours  \
# 0                 2.0          5-6 hours        Healthy               3.0
# 1                 5.0          5-6 hours       Moderate               3.0
# 2                 5.0  Less than 5 hours        Healthy               9.0
# 3                 2.0          7-8 hours       Moderate               4.0
# 4                 3.0          5-6 hours       Moderate               1.0
#
#    Financial Stress Family History of Mental Illness  Depression
# 0               1.0                               No           1
# ...

# %%
st['Sleep Duration'] = le.fit_transform(st['Sleep Duration'])

# %%
st['Dietary Habits'] = le.fit_transform(st['Dietary Habits'])

# %%
st['Family History of Mental Illness'] = le.fit_transform(st['Family History of Mental Illness'])

# %%
st.head()
# Out:
#    Gender   Age  City  Profession  Academic Pressure  CGPA  \
# 0       1  33.0    51          11                5.0  8.97
# 1       0  24.0     3          11                2.0  5.90
# 2       1  31.0    44          11                3.0  7.03
# 3       0  28.0    49          11                3.0  5.59
# 4       0  25.0    16          11                4.0  8.13
#
#    Study Satisfaction  Sleep Duration  Dietary Habits  Work/Study Hours  \
# 0                 2.0               0               0               3.0
# 1                 5.0               0               1               3.0
# 2                 5.0               2               0               9.0
# 3                 2.0               1               1               4.0
# 4                 3.0               0               1               1.0
#
#    Financial Stress  Family History of Mental Illness  Depression
# 0               1.0                                 0           1
# ...

# %%
st.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Gender                            27901 non-null  int64
#  1   Age                               27901 non-null  float64
#  2   City                              27901 non-null  int64
#  3   Profession                        27901 non-null  int64
#  4   Academic Pressure                 27901 non-null  float64
#  5   CGPA                              27901 non-null  float64
#  6   Study Satisfaction                27901 non-null  float64
#  7   Sleep Duration                    27901 non-null  int64
#  8   Dietary Habits                    27901 non-null  int64
#  9   Work/Study Hours                  27901 non-null  float64
#  10  Financial Stress                  27898 non-null  float64
#  11  Family History of Mental Illness  27901 non-null  int64
# ...

# %%
st['Financial Stress'] = st['Financial Stress'].astype('float32')

# %%
st.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Gender                            27901 non-null  int64
#  1   Age                               27901 non-null  float64
#  2   City                              27901 non-null  int64
#  3   Profession                        27901 non-null  int64
#  4   Academic Pressure                 27901 non-null  float64
#  5   CGPA                              27901 non-null  float64
#  6   Study Satisfaction                27901 non-null  float64
#  7   Sleep Duration                    27901 non-null  int64
#  8   Dietary Habits                    27901 non-null  int64
#  9   Work/Study Hours                  27901 non-null  float64
#  10  Financial Stress                  27898 non-null  float32
#  11  Family History of Mental Illness  27901 non-null  int64
# ...

# %% [markdown]
# ### Separating Input and Output Data

# %%
st.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Profession', 'Academic Pressure', 'CGPA',
#        'Study Satisfaction', 'Sleep Duration', 'Dietary Habits',
#        'Work/Study Hours', 'Financial Stress',
#        'Family History of Mental Illness', 'Depression'],
#       dtype='str')

# %%
x = st[['Gender', 'Age', 'City', 'Profession', 'Academic Pressure', 'CGPA',
       'Study Satisfaction', 'Sleep Duration', 'Dietary Habits',
       'Work/Study Hours', 'Financial Stress',
       'Family History of Mental Illness']]

# %%
y = st['Depression']

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
x = ss.fit_transform(x)

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 27896    0
# 27897    0
# 27898    0
# 27899    1
# 27900    1
# Name: Depression, Length: 27901, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (22320, 12)

# %%
x_test.shape
# Out:
# (5581, 12)

# %% [markdown]
# ### Logestic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")

x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7926894821716538

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(max_depth = 5)

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_predict = tree.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7729797527324852

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rf.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7857014871886758

# %% [markdown]
# ### XGB Classifier

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(n_estimators = 100)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict = xgb.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7824762587349937

# %% [markdown]
# ### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(n_estimators = 100)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
y_predict = ada.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7926894821716538

# %% [markdown]
# ### Cat Boost Classifier

# %%
from catboost import CatBoostClassifier

# %%
cat = CatBoostClassifier(n_estimators=100)

# %%
cat.fit(x_train,y_train)
# Out:
# Learning rate set to 0.320499
# 0:	learn: 0.5993703	total: 5.02ms	remaining: 497ms
# 1:	learn: 0.5437613	total: 10ms	remaining: 492ms
# 2:	learn: 0.5065655	total: 14.1ms	remaining: 457ms
# 3:	learn: 0.4850408	total: 20.2ms	remaining: 484ms
# 4:	learn: 0.4693510	total: 25.7ms	remaining: 489ms
# 5:	learn: 0.4594111	total: 29.9ms	remaining: 469ms
# 6:	learn: 0.4525808	total: 33ms	remaining: 439ms
# 7:	learn: 0.4479053	total: 36.7ms	remaining: 422ms
# 8:	learn: 0.4434415	total: 40.7ms	remaining: 412ms
# 9:	learn: 0.4405832	total: 45.4ms	remaining: 409ms
# 10:	learn: 0.4381691	total: 49.1ms	remaining: 397ms
# 11:	learn: 0.4357260	total: 53.7ms	remaining: 394ms
# 12:	learn: 0.4343961	total: 57ms	remaining: 382ms
# 13:	learn: 0.4327161	total: 61.2ms	remaining: 376ms
# 14:	learn: 0.4311313	total: 64.7ms	remaining: 367ms
# 15:	learn: 0.4295008	total: 69.6ms	remaining: 366ms
# 16:	learn: 0.4283357	total: 73.4ms	remaining: 358ms
# 17:	learn: 0.4277880	total: 77.7ms	remaining: 354ms
# ...

# %%
y_predict = cat.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7917935853789644

# %% [markdown]
# ### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7536283820103924

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC

svc = SVC(kernel = 'rbf')

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict = svc.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7939437376814191

# %% [markdown]
# ### Naive Bayes Algorithm ---> Bernoulli Naive Bayes
# ###                       ---> Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
bn = BernoulliNB()

# %%
bn.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_predict = bn.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7502239741981723

# %%
from sklearn.naive_bayes import MultinomialNB
mn = MultinomialNB()

# %%
## mn.fit(x_train,y_train)

# %% [markdown]
# ### Bagging Classifier ---> Ensemble Learning

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag = BaggingClassifier(n_estimators = 100)

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier(n_estimators=100)

# %%
y_predict = bag.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.77512990503494

# %% [markdown]
# ### Stacking Classifier ---> Ensemble Learning ---> We can choose with the Specific models to come up with the final claasification

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier

estimators = [('rf',RandomForestClassifier()),('bc',BaggingClassifier())]

stacking = StackingClassifier(estimators= estimators,final_estimator = AdaBoostClassifier())

# %%
stacking.fit(x_train,y_train)
# Out:
# StackingClassifier(estimators=[('rf', RandomForestClassifier()),
#                                ('bc', BaggingClassifier())],
#                    final_estimator=AdaBoostClassifier())

# %%
y_predict = stacking.predict(x_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.7806844651496148

# %% [markdown]
# ## Hyperparameter Tuning --- > GridSearchCV
# ##                       --- > RandomSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'n_estimators':[100,200,300],'max_depth' : [4,6,8]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,cv=5)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [4, 6, 8],
#                          'n_estimators': [100, 200, 300]})

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 8, 'n_estimators': 200}
# 0.4013261728787102

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'n_estimators':[100,200],'max_depth' : [4,6,8]}
random = RandomizedSearchCV(RandomForestRegressor(),param_distributions=param_grid,n_iter=10,cv=5)

# %%
random.fit(x_train,y_train)
# Out:
# d:\AI Dev\.venv\Lib\site-packages\sklearn\model_selection\_search.py:327: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [4, 6, 8],
#                                         'n_estimators': [100, 200]})

# %%
print(random.best_params_)
print(random.best_score_)
# Out:
# {'n_estimators': 200, 'max_depth': 8}
# 0.4011958370351424

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import StackingRegressor

# %%
model = RandomForestRegressor(n_estimators = 100)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict = model.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.30593262856118975

# %%
import pickle 

with open('model.pkl','wb') as file:
    pickle.dump(model,file)

# %%
with open('model.pkl','rb') as file:
    new_model = pickle.load(file)

# %%
new_model
# Out:
# RandomForestRegressor()
