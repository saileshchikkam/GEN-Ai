# %% [markdown]
# ## Data Gathering

# %%
## import all required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\AI Dev\.venv\Lib\site-packages (1.9.1)
# Requirement already satisfied: numpy>=1.24.1 in d:\AI Dev\.venv\Lib\site-packages (from scikit-learn) (2.5.3)
# Requirement already satisfied: scipy>=1.10.0 in d:\AI Dev\.venv\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in d:\AI Dev\.venv\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in d:\AI Dev\.venv\Lib\site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in d:\AI Dev\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in d:\AI Dev\.venv\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
import sklearn

# %% [markdown]
# ### Data Gathering

# %%
df = pd.read_csv('International_Education_Costs.csv')

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# 2               72.5      1600           235            900           1.35
# 3               71.2      1400           450            650           1.52
# 4               70.5      1100            75            550           0.92

# %% [markdown]
# ### Data Exploration

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# 2               72.5      1600           235            900           1.35
# 3               71.2      1400           450            650           1.52
# 4               70.5      1100            75            550           0.92

# %%
df.shape
# Out:
# (907, 12)

# %%
df.tail()
# Out:
#           Country        City                University               Program  \
# 902        France  Strasbourg  University of Strasbourg        Data Analytics
# 903      Malaysia       Nilai                      USIM      Computer Science
# 904  Saudi Arabia     Al-Ahsa    King Faisal University   Information Systems
# 905           USA     Seattle  University of Washington  Software Development
# 906            UK  Nottingham  University of Nottingham      Data Engineering
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 902    Master             2.0         4000               70.2      1000
# 903  Bachelor             3.0         6800               50.5       400
# 904    Master             2.0         4200               64.2       600
# 905       PhD             5.0        50000               77.8      2000
# 906    Master             2.0        34000               61.2       800
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 902            99            850           0.92
# 903           120            400           4.65
# 904           200            800           3.75
# 905           160           1500           1.00
# 906           485            800           0.79

# %%
df.sample()
# Out:
#     Country     City                University               Program   Level  \
# 543     USA  Seattle  University of Washington  Computer Engineering  Master
#
#      Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  Visa_Fee_USD  \
# 543             2.0        51000               77.8      2100           160
#
#      Insurance_USD  Exchange_Rate
# 543           1500            1.0

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# 75%      240.000000     800.000000       7.150000
# max      490.000000    1500.000000   42150.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 85.2 KB

# %%
df.shape
# Out:
# (907, 12)

# %%
df.size
# Out:
# 10884

# %%
df.dtypes ## float64 can be changed to float32
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Country'].value_counts()  # 71 countries
# Out:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Taiwan             1
# Czech Republic     1
# South Africa       1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64

# %%
df['Country'].unique()  # 71 countries
# Out:
# <StringArray>
# [               'USA',                 'UK',             'Canada',
#           'Australia',            'Germany',              'Japan',
#         'Netherlands',          'Singapore',             'France',
#         'Switzerland',             'Sweden',            'Denmark',
#               'China',        'South Korea',            'Ireland',
#         'New Zealand',            'Austria',            'Belgium',
#           'Hong Kong',           'Portugal',             'Israel',
#              'Taiwan',     'Czech Republic',              'India',
#              'Poland',           'Malaysia',              'Spain',
#               'Italy',            'Finland',             'Norway',
#              'Brazil',             'Turkey',             'Russia',
#              'Mexico',             'Greece',           'Thailand',
#                 'UAE',       'South Africa',              'Egypt',
#           'Argentina',          'Indonesia',       'Saudi Arabia',
#             'Nigeria',            'Vietnam',            'Hungary',
#             'Iceland',           'Colombia',            'Romania',
#          'Luxembourg',            'Tunisia',             'Cyprus',
#             'Croatia', 'Dominican Republic',            'Morocco',
#                'Peru',            'Ecuador',            'Lebanon',
#             'Bahrain',            'Uruguay',           'Bulgaria',
#               'Ghana',            'Algeria',             'Panama',
#          'Bangladesh',             'Kuwait',            'Ukraine',
#            'Slovenia',             'Serbia',               'Iran',
#          'Uzbekistan',        'El Salvador']
# Length: 71, dtype: str

# %%
df[df['Country'] == 'India']
# Out:
#     Country       City                   University                  Program  \
# 44    India  Bangalore  Indian Institute of Science         Computer Science
# 648   India  Bangalore  Indian Institute of Science             Data Science
# 654   India     Mumbai                   IIT Bombay     Computer Engineering
# 659   India      Delhi                    IIT Delhi  Artificial Intelligence
# 665   India    Chennai                   IIT Madras     Software Engineering
# 671   India  Hyderabad                IIT Hyderabad           Data Analytics
# 677   India       Pune                     IIT Pune         Computer Science
# 683   India     Kanpur                   IIT Kanpur  Artificial Intelligence
#
#       Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 44   Master             2.0         2500               45.6       500
# 648     PhD             4.0         2000               45.2       300
# 654  Master             2.0         1800               47.5       350
# 659     PhD             4.0         1900               44.8       320
# 665  Master             2.0         1700               42.4       280
# 671     PhD             4.0         1800               41.2       260
# 677  Master             2.0         1600               40.5       250
# 683     PhD             4.0         1900               39.8       240
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 44            200            300          83.20
# 648           180            300          82.75
# 654           180            300          82.75
# 659           180            300          82.75
# 665           180            300          82.75
# 671           180            300          82.75
# 677           180            300          82.75
# 683           180            300          82.75

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
df['City'].value_counts()  # 71 countries
# Out:
# City
# Singapore    18
# Melbourne    11
# Sydney       11
# London       10
# Canberra      8
#              ..
# Tabuk         1
# Shah Alam     1
# Makkah        1
# Nilai         1
# Al-Ahsa       1
# Name: count, Length: 556, dtype: int64

# %%
df['City'].unique()
# Out:
# <StringArray>
# ['Cambridge',    'London',   'Toronto', 'Melbourne',    'Munich',     'Tokyo',
#  'Amsterdam', 'Singapore',     'Paris',    'Zurich',
#  ...
#  'Cyberjaya',    'Dammam',     'Bangi',      'Taif',    'Melaka',     'Tabuk',
#  'Shah Alam',    'Makkah',     'Nilai',   'Al-Ahsa']
# Length: 556, dtype: str

# %%
df['Program'].value_counts()  # 71 countries
# Out:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64

# %%
df['Level'].value_counts()  # 71 countries
# Out:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
df['Duration_Years'].min()
# Out:
# np.float64(1.0)

# %%
df['Duration_Years'].max()
# Out:
# np.float64(5.0)

# %%
df['Duration_Years'].mean()
# Out:
# np.float64(2.8368246968026463)

# %% [markdown]
# ### Data Cleaning

# %%
## isnull() function is used to find the missing values in the dataset. It returns a boolean value indicating whether each element is null or not.
df.isnull().sum() ## there is no null values in the dataset. So, we don't need to handle missing values.
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
df.duplicated().sum() ## there is no duplicate values in the dataset. So, we don't need to handle duplicate values.
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
## astype() function is used to convert the data type of a column in a DataFrame. It takes the desired data type as an argument and returns a new DataFrame with the specified column converted to that data type.
df['Duration_Years'] = df['Duration_Years'].astype('float32')
df['Rent_USD'] = df['Rent_USD'].astype('float32')
df['Tuition_USD'] = df['Tuition_USD'].astype('int32')
df['Visa_Fee_USD'] = df['Visa_Fee_USD'].astype('int32')
df['Insurance_USD'] = df['Insurance_USD'].astype('int32')

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float32
# Tuition_USD            int32
# Living_Cost_Index    float64
# Rent_USD             float32
# Visa_Fee_USD           int32
# Insurance_USD          int32
# Exchange_Rate        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    float32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float32(2), float64(2), int32(3), str(5)
# memory usage: 67.4 KB

# %% [markdown]
# ### EDA Exploratory Data Analysis

# %%
## Univariate Analysis

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# UK             93
# Australia      86
# USA            78
# Canada         76
# Germany        33
# France         27
# South Korea    23
# Netherlands    21
# Switzerland    20
# Singapore      18
# Name: count, dtype: int64

# %%
country = df[df['Country'].isin(['USA', 'UK', 'Canada', 'Australia', 'Germany', 'France', 'South Korea','Netherlands', 'Switzerland', 'Singapore'])]

# %%
sns.countplot(x='Country', data=country) ## labels overlaped
plt.xticks(rotation='vertical')
plt.show()

# %%
df['City'].value_counts().head()
# Out:
# City
# Singapore    18
# Melbourne    11
# Sydney       11
# London       10
# Canberra      8
# Name: count, dtype: int64

# %%
city = df[df['City'].isin(['London', 'Sydney','Singapore','Melbourne','Canberra'])]

# %%
city.shape
# Out:
# (58, 12)

# %%
sns.countplot(x='Level', data=df)
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %%
d1 = df[df['Level'] == 'Master'].head(150)
d2 = df[df['Level'] == 'Bachelor'].head(150)
d3 = df[df['Level'] == 'PhD'].head(150)

# %%
d1.shape
# Out:
# (150, 12)

# %%
d2.shape
# Out:
# (150, 12)

# %%
d3.shape
# Out:
# (150, 12)

# %%
## concatenate the three dataframes into a single dataframe
d4 = pd.concat([d1, d2, d3], axis=0)

# %%
d4.shape ## concatenated
# Out:
# (450, 12)

# %%
df.shape
# Out:
# (907, 12)

# %%
## df dataframe
sns.histplot(data = df, x = 'Duration_Years')
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Count'>

# %%
## d4 dataframe ---> 150 each of Level
sns.histplot(data = d4, x = 'Duration_Years')
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
sns.histplot(data=df,x='Tuition_USD')
# Out:
# <Axes: xlabel='Tuition_USD', ylabel='Count'>

# %%
sns.histplot(data = df,x = 'Rent_USD')
# Out:
# <Axes: xlabel='Rent_USD', ylabel='Count'>

# %%
sns.kdeplot(data = df, x= 'Rent_USD')
plt.grid()

# %%
sns.boxplot(data = df, x= 'Rent_USD')
# Out:
# <Axes: xlabel='Rent_USD'>

# %%
## bivariante Analysis

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    float32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float32(2), float64(2), int32(3), str(5)
# memory usage: 67.4 KB

# %%
## Tuition fee for the top 10 countries
sns.barplot(data = country, x = 'Country', y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
country.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5    2200.0           160           1500           1.00
# 1               75.8    1800.0           485            800           0.79
# 2               72.5    1600.0           235            900           1.35
# 3               71.2    1400.0           450            650           1.52
# 4               70.5    1100.0            75            550           0.92

# %%
## Visa_Fee Country wise ## bivariate analysis
sns.barplot(data = country, x = 'Country', y = 'Visa_Fee_USD')
plt.xticks(rotation=45)
plt.show()

# %%
df['University'].value_counts().head(10)
# Out:
# University
# University of Washington           6
# University of Melbourne            5
# Stanford University                5
# Australian National University     5
# University of Sydney               5
# University of Adelaide             5
# University of Western Australia    5
# Griffith University                5
# University of Tasmania             5
# University of Newcastle            5
# Name: count, dtype: int64

# %%
university = df[df['University'].isin(['University of Washington', 'University of Melbourne', 'Stanford University', 'Australian National University', 'University of Sydney', 'University of Adelaide', 'University of Western Australia', 'Griffith University', 'University of Tasmania', 'University of Newcastle'])]

# %%
university.shape
# Out:
# (51, 12)

# %%
sns.barplot(data = university, x = 'University', y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data = university, x = 'University', y = 'Duration_Years')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.lineplot(data = university, x = 'University', y = 'Duration_Years')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
sns.lineplot(data = df, x = 'Duration_Years',y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
sns.scatterplot(data = df, x = 'Duration_Years',y = 'Tuition_USD')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
## Top 10 countries and  Top 10 Universities Tuition Fees (HeatMap)

# %%
country['Country'].value_counts()
# Out:
# Country
# UK             93
# Australia      86
# USA            78
# Canada         76
# Germany        33
# France         27
# South Korea    23
# Netherlands    21
# Switzerland    20
# Singapore      18
# Name: count, dtype: int64

# %%
country['University'].value_counts().head(10)
# Out:
# University
# University of Washington           6
# University of Melbourne            5
# Stanford University                5
# Australian National University     5
# University of Sydney               5
# University of Adelaide             5
# University of Western Australia    5
# Griffith University                5
# University of Tasmania             5
# University of Newcastle            5
# Name: count, dtype: int64

# %%
university = country[country['University'].isin(['University of Washington', 'University of Melbourne', 'Stanford University', 'Australian National University', 'University of Sydney', 'University of Adelaide', 'University of Western Australia', 'Griffith University', 'University of Tasmania', 'University of Newcastle'])]

# %%
## pivot table ---> filtered table

data = university.pivot_table(index='Country', columns='University', values='Tuition_USD', aggfunc='mean')

# %%
sns.heatmap(data)
# Out:
# <Axes: xlabel='University', ylabel='Country'>

# %% [markdown]
# ### Feature Engineering and Model Building

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5    2200.0           160           1500           1.00
# 1               75.8    1800.0           485            800           0.79
# 2               72.5    1600.0           235            900           1.35
# 3               71.2    1400.0           450            650           1.52
# 4               70.5    1100.0            75            550           0.92

# %%
## addition of Tuition_Fee & Rent_USD
## New output column = Total_Cost_USD
df['Total_Cost_USD'] = df['Tuition_USD'] + df['Rent_USD']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    float32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
#  12  Total_Cost_USD     907 non-null    float64
# dtypes: float32(2), float64(3), int32(3), str(5)
# memory usage: 74.5 KB

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate  \
# 0               83.5    2200.0           160           1500           1.00
# 1               75.8    1800.0           485            800           0.79
# 2               72.5    1600.0           235            900           1.35
# 3               71.2    1400.0           450            650           1.52
# 4               70.5    1100.0            75            550           0.92
#
#    Total_Cost_USD
# 0         57600.0
# 1         43000.0
# 2         40100.0
# 3         43400.0
# 4          1600.0

# %%
df['Total_Cost_USD']
# Out:
# 0      57600.0
# 1      43000.0
# 2      40100.0
# 3      43400.0
# 4       1600.0
#         ...
# 902     5000.0
# 903     7200.0
# 904     4800.0
# 905    52000.0
# 906    34800.0
# Name: Total_Cost_USD, Length: 907, dtype: float64

# %%
## Feature Selection ----> Mention all column names inside a list and the list should be inside a dataframe
df = df[['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years', 'Living_Cost_Index', 'Visa_Fee_USD', 'Insurance_USD', 'Total_Cost_USD']]

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Living_Cost_Index  \
# 0        Computer Science  Master             2.0               83.5
# 1            Data Science  Master             1.0               75.8
# 2      Business Analytics  Master             2.0               72.5
# 3             Engineering  Master             2.0               71.2
# 4  Mechanical Engineering  Master             2.0               70.5
#
#    Visa_Fee_USD  Insurance_USD  Total_Cost_USD
# 0           160           1500         57600.0
# 1           485            800         43000.0
# 2           235            900         40100.0
# 3           450            650         43400.0
# 4            75            550          1600.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float32
#  6   Living_Cost_Index  907 non-null    float64
#  7   Visa_Fee_USD       907 non-null    int32
#  8   Insurance_USD      907 non-null    int32
#  9   Total_Cost_USD     907 non-null    float64
# dtypes: float32(1), float64(2), int32(2), str(5)
# memory usage: 60.4 KB

# %%
## Label Encoding ----> Convert Categorical data into Numerical data
## or Feature Encoding ---> we want to feed this data to a mathematical model
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() ## object of LabelEncoder class

# %%
df['Country'] = le.fit_transform(df['Country']) # categorical to numerical

# %%
df.head()
# Out:
#    Country       City                      University                 Program  \
# 0       66  Cambridge              Harvard University        Computer Science
# 1       65     London         Imperial College London            Data Science
# 2        9    Toronto           University of Toronto      Business Analytics
# 3        2  Melbourne         University of Melbourne             Engineering
# 4       22     Munich  Technical University of Munich  Mechanical Engineering
#
#     Level  Duration_Years  Living_Cost_Index  Visa_Fee_USD  Insurance_USD  \
# 0  Master             2.0               83.5           160           1500
# 1  Master             1.0               75.8           485            800
# 2  Master             2.0               72.5           235            900
# 3  Master             2.0               71.2           450            650
# 4  Master             2.0               70.5            75            550
#
#    Total_Cost_USD
# 0         57600.0
# 1         43000.0
# 2         40100.0
# 3         43400.0
# 4          1600.0

# %%
df['City']=le.fit_transform(df['City'])
df['University']=le.fit_transform(df['University'])
df['Program']=le.fit_transform(df['Program'])
df['Level']=le.fit_transform(df['Level'])

# %%
df.head() ## see everything is numerical 😁
# Out:
#    Country  City  University  Program  Level  Duration_Years  \
# 0       66    84         101       17      1             2.0
# 1       65   283         128       27      1             1.0
# 2        9   503         572        9      1             2.0
# 3        2   313         495       44      1             2.0
# 4       22   330         307       66      1             2.0
#
#    Living_Cost_Index  Visa_Fee_USD  Insurance_USD  Total_Cost_USD
# 0               83.5           160           1500         57600.0
# 1               75.8           485            800         43000.0
# 2               72.5           235            900         40100.0
# 3               71.2           450            650         43400.0
# 4               70.5            75            550          1600.0

# %%
## now we have proper columns lets feed
## Before that lets separete the input and output columns

# %%
x = df.iloc[:, :-1] ## input columns[rows,cols]
y = df['Total_Cost_USD'] ## output column

# %%
x
# Out:
#      Country  City  University  Program  Level  Duration_Years  \
# 0         66    84         101       17      1             2.0
# 1         65   283         128       27      1             1.0
# 2          9   503         572        9      1             2.0
# 3          2   313         495       44      1             2.0
# 4         22   330         307       66      1             2.0
# ..       ...   ...         ...      ...    ...             ...
# 902       21   469         556       25      1             2.0
# 903       38   344         345       17      0             3.0
# 904       51    12         154       57      1             2.0
# 905       66   441         585       84      2             5.0
# 906       65   347         512       26      1             2.0
#
#      Living_Cost_Index  Visa_Fee_USD  Insurance_USD
# 0                 83.5           160           1500
# 1                 75.8           485            800
# 2                 72.5           235            900
# 3                 71.2           450            650
# 4                 70.5            75            550
# ..                 ...           ...            ...
# 902               70.2            99            850
# 903               50.5           120            400
# 904               64.2           200            800
# 905               77.8           160           1500
# 906               61.2           485            800
#
# [907 rows x 9 columns]

# %%
y
# Out:
# 0      57600.0
# 1      43000.0
# 2      40100.0
# 3      43400.0
# 4       1600.0
#         ...
# 902     5000.0
# 903     7200.0
# 904     4800.0
# 905    52000.0
# 906    34800.0
# Name: Total_Cost_USD, Length: 907, dtype: float64

# %%
## Feature Scaling ----> Standardization or Normalization data
from sklearn.preprocessing import StandardScaler

s = StandardScaler()

# %%
s.fit_transform (x) ##inputs 'x'
# Out:
# array([[ 1.29937861, -1.18314994, -1.25623694, ...,  1.35689951,
#         -0.3585248 ,  2.49821139],
#        [ 1.25678296,  0.02539721, -1.10697039, ...,  0.80880148,
#          1.90854833,  0.31206552],
#        [-1.12857335,  1.3614795 ,  1.3476352 , ...,  0.57390232,
#          0.16464592,  0.62437207],
#        ...,
#        [ 0.66044389, -1.62041323, -0.96323222, ..., -0.01690464,
#         -0.07950042,  0.31206552],
#        [ 1.29937861,  0.98494722,  1.41950429, ...,  0.9511646 ,
#         -0.3585248 ,  2.49821139],
#        [ 1.25678296,  0.4140757 ,  1.01593175, ..., -0.23044933,
#          1.90854833,  0.31206552]], shape=(907, 9))

# %%
## no standard scalar for output column 'y' because we are predicting the cost in USD

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train.shape
# Out:
# (725, 9)

# %%
x_test.shape
# Out:
# (182, 9)

# %%
y_train.shape
# Out:
# (725,)

# %%
y_test.shape
# Out:
# (182,)

# %% [markdown]
# ### Model Training and Evaluation

# %%
## now we have proper data now lets feed to the model and train the model
## into the algorithms and see which algorithm is best for our dataset

# %%
## Regression and Classificatiom

# %%
## Regression ---> 1. Linear Regression
##                 2. Ridge Regression
##                 3. Lasso Regression
##                 4. Elastic Net - Regression
##                 5. Decision Tree Regressor
##                 6. Random Forest Regressor
##                 7. XGBoost Regressor
##                 8. AdaBoost Regressor
##                 9. CatBoost Regressor
##                 10. KNeighbour Regressor
##                 11. SVR (Support Vector Regressor)
##                 12. Bagging regressor
##                 13. Stacking regressor

# %%
## Evaluation Metrics --> how correct are the models outputs is?
##                    --> 1. Mean Squared Error (MSE)
##                    --> 2. Root Mean Squared Error (RMSE)
##                    --> 3. Mean Absolute Error (MAE)

# %% [markdown]
# ### Regression

# %% [markdown]
# ### 1. Linear Regressison

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
## fit() ---> To train your machine learning model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
## predict()
y_predict = lr.predict(x_test)

# %%
## Evaluation Metrics
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_predict) ### huge error
# Out:
# 8659.427341273538

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 130433373.64519878

# %% [markdown]
# ### 2. Ridge Regression

# %%
from sklearn.linear_model import Ridge
r = Ridge()

# %%
r.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_predict = r.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 8659.430791591045

# %% [markdown]
# ### 3. Lasso Regression

# %%
from sklearn.linear_model import Lasso
l = Lasso(alpha = 0.1)

# %%
l.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_predict = l.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 8659.412655816815

# %% [markdown]
# ### 4. Elastic Net Algorithm

# %%
from sklearn.linear_model import ElasticNet

e = ElasticNet(alpha=0.01, l1_ratio=0.5)

# %%
e.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.01)

# %%
y_predict = e.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 8659.439321580785

# %% [markdown]
# ### 5. Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(max_depth = 5)

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_predict = tree.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## finally reduced 😅
# Out:
# 4136.742081363999

# %%
## decision tree better than linear regression

# %% [markdown]
# ### 6. Random Forest Regressor
# ### (Ensemble Learning Technique) --->combination of multiple decision trees

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators = 100)

# %%
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict = forest.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## best model across we see
# Out:
# 2614.2999999999997

# %% [markdown]
# ### Ensemble Learning --->
# ### 1. XGBoost Regressor
# ### 2. Ada Boost Regressor
# ### 3. Cat Boost Regressor

# %% [markdown]
# ### 7. Ada Boost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada = AdaBoostRegressor(n_estimators = 100)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=100)

# %%
y_predict = ada.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict) ## OK
# Out:
# 5283.096248386526

# %% [markdown]
# ### 8. XG Boost Regressor

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.4.1-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in d:\AI Dev\.venv\Lib\site-packages (from xgboost) (2.5.3)
# Requirement already satisfied: scipy in d:\AI Dev\.venv\Lib\site-packages (from xgboost) (1.18.1)
# Downloading xgboost-3.4.1-py3-none-win_amd64.whl (48.9 MB)
#    ---------------------------------------- 0.0/48.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/48.9 MB ? eta -:--:--
#     --------------------------------------- 1.0/48.9 MB 7.2 MB/s eta 0:00:07
#    - -------------------------------------- 1.6/48.9 MB 4.2 MB/s eta 0:00:12
#    - -------------------------------------- 2.4/48.9 MB 4.2 MB/s eta 0:00:12
#    -- ------------------------------------- 3.4/48.9 MB 4.3 MB/s eta 0:00:11
#    --- ------------------------------------ 4.7/48.9 MB 4.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 7.3/48.9 MB 6.0 MB/s eta 0:00:07
#    -------- ------------------------------- 10.2/48.9 MB 7.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 12.6/48.9 MB 7.6 MB/s eta 0:00:05
#    ------------ --------------------------- 14.9/48.9 MB 8.0 MB/s eta 0:00:05
#    -------------- ------------------------- 17.3/48.9 MB 8.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 19.9/48.9 MB 8.6 MB/s eta 0:00:04
#    ------------------ --------------------- 22.5/48.9 MB 8.9 MB/s eta 0:00:03
#    -------------------- ------------------- 25.4/48.9 MB 9.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 28.0/48.9 MB 9.5 MB/s eta 0:00:03
#    ------------------------ --------------- 30.1/48.9 MB 9.6 MB/s eta 0:00:02
#    -------------------------- ------------- 32.5/48.9 MB 9.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 35.1/48.9 MB 9.7 MB/s eta 0:00:02
#    ------------------------------ --------- 37.5/48.9 MB 9.8 MB/s eta 0:00:02
#    -------------------------------- ------- 39.6/48.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 42.2/48.9 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 44.6/48.9 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------- -- 46.4/48.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  48.5/48.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 48.9/48.9 MB 9.8 MB/s  0:00:05
# Installing collected packages: xgboost
# Successfully installed xgboost-3.4.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(n_estimators = 100)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict = xgb.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## XGBoost we got best results
# Out:
# 2086.7581218677565

# %% [markdown]
# ### 9. Cat Boost Algorithm

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in d:\AI Dev\.venv\Lib\site-packages (from catboost) (3.11.2)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in d:\AI Dev\.venv\Lib\site-packages (from catboost) (2.5.3)
# Requirement already satisfied: pandas<4.0,>=0.24 in d:\AI Dev\.venv\Lib\site-packages (from catboost) (3.0.5)
# Requirement already satisfied: scipy in d:\AI Dev\.venv\Lib\site-packages (from catboost) (1.18.1)
# Collecting plotly (from catboost)
#   Downloading plotly-7.0.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: six in d:\AI Dev\.venv\Lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\AI Dev\.venv\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\AI Dev\.venv\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2026.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (26.3)
# Requirement already satisfied: pillow>=9 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\AI Dev\.venv\Lib\site-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in d:\AI Dev\.venv\Lib\site-packages (from plotly->catboost) (2.26.0)
# Downloading catboost-1.2.10-cp312-cp312-win_amd64.whl (100.2 MB)
#    ---------------------------------------- 0.0/100.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/100.2 MB ? eta -:--:--
#     --------------------------------------- 1.8/100.2 MB 7.2 MB/s eta 0:00:14
#    - -------------------------------------- 3.7/100.2 MB 7.8 MB/s eta 0:00:13
#    -- ------------------------------------- 5.5/100.2 MB 8.2 MB/s eta 0:00:12
#    --- ------------------------------------ 7.6/100.2 MB 8.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 10.2/100.2 MB 9.0 MB/s eta 0:00:11
#    ---- ----------------------------------- 12.3/100.2 MB 9.4 MB/s eta 0:00:10
#    ----- ---------------------------------- 14.9/100.2 MB 9.7 MB/s eta 0:00:09
#    ------- -------------------------------- 17.8/100.2 MB 10.0 MB/s eta 0:00:09
#    -------- ------------------------------- 20.2/100.2 MB 10.3 MB/s eta 0:00:08
#    --------- ------------------------------ 23.1/100.2 MB 10.6 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.7/100.2 MB 10.7 MB/s eta 0:00:07
#    ----------- ---------------------------- 28.0/100.2 MB 10.7 MB/s eta 0:00:07
#    ------------ --------------------------- 30.7/100.2 MB 10.8 MB/s eta 0:00:07
#    ------------- -------------------------- 33.3/100.2 MB 11.0 MB/s eta 0:00:07
#    -------------- ------------------------- 35.4/100.2 MB 10.9 MB/s eta 0:00:06
#    --------------- ------------------------ 38.0/100.2 MB 10.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 40.4/100.2 MB 11.0 MB/s eta 0:00:06
#    ----------------- ---------------------- 42.7/100.2 MB 11.0 MB/s eta 0:00:06
#    ------------------ --------------------- 45.6/100.2 MB 11.1 MB/s eta 0:00:05
#    ------------------- -------------------- 48.2/100.2 MB 11.2 MB/s eta 0:00:05
#    -------------------- ------------------- 50.6/100.2 MB 11.1 MB/s eta 0:00:05
#    --------------------- ------------------ 53.2/100.2 MB 11.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 55.6/100.2 MB 11.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 58.5/100.2 MB 11.3 MB/s eta 0:00:04
#    ------------------------ --------------- 61.1/100.2 MB 11.3 MB/s eta 0:00:04
#    ------------------------- -------------- 63.7/100.2 MB 11.3 MB/s eta 0:00:04
#    -------------------------- ------------- 66.1/100.2 MB 11.4 MB/s eta 0:00:04
#    --------------------------- ------------ 68.9/100.2 MB 11.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 71.6/100.2 MB 11.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 74.4/100.2 MB 11.5 MB/s eta 0:00:03
#    ------------------------------ --------- 77.6/100.2 MB 11.6 MB/s eta 0:00:02
#    -------------------------------- ------- 80.2/100.2 MB 11.6 MB/s eta 0:00:02
#    --------------------------------- ------ 82.8/100.2 MB 11.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.5/100.2 MB 11.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.1/100.2 MB 11.7 MB/s eta 0:00:02
#    ------------------------------------ --- 90.7/100.2 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------- -- 93.3/100.2 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 96.2/100.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  98.6/100.2 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  100.1/100.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 100.2/100.2 MB 11.4 MB/s  0:00:08
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading plotly-7.0.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    --------- ------------------------------ 2.1/9.1 MB 10.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.9/9.1 MB 9.0 MB/s eta 0:00:01
#    ------------------------ --------------- 5.5/9.1 MB 8.4 MB/s eta 0:00:01
#    --------------------------------- ------ 7.6/9.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  8.9/9.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  8.9/9.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 6.9 MB/s  0:00:01
# Installing collected packages: plotly, graphviz, catboost
#
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ---------------------------------------- 0/3 [plotly]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    ------------- -------------------------- 1/3 [graphviz]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    -------------------------- ------------- 2/3 [catboost]
#    ---------------------------------------- 3/3 [catboost]
#
# Successfully installed catboost-1.2.10 graphviz-0.21 plotly-7.0.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (d:\AI Dev\.venv\Lib\site-packages)

# %%
from catboost import CatBoostRegressor

# %%
cat = CatBoostRegressor(n_estimators=100)

# %%
cat.fit(x_train,y_train)
# Out:
# Learning rate set to 0.252996
# 0:	learn: 14317.4842791	total: 3.19ms	remaining: 316ms
# 1:	learn: 12451.8189470	total: 5.48ms	remaining: 269ms
# 2:	learn: 10837.6169670	total: 7.22ms	remaining: 233ms
# 3:	learn: 9347.8058282	total: 9.32ms	remaining: 224ms
# 4:	learn: 8353.8578871	total: 11.6ms	remaining: 221ms
# 5:	learn: 7550.6326945	total: 13.4ms	remaining: 210ms
# 6:	learn: 6926.6977073	total: 15ms	remaining: 200ms
# 7:	learn: 6486.8579005	total: 17.8ms	remaining: 204ms
# 8:	learn: 6068.8307293	total: 19.7ms	remaining: 199ms
# 9:	learn: 5796.1440443	total: 21.3ms	remaining: 192ms
# 10:	learn: 5467.9974198	total: 23.4ms	remaining: 189ms
# 11:	learn: 5212.1054451	total: 25.9ms	remaining: 190ms
# 12:	learn: 5133.0999628	total: 27.8ms	remaining: 186ms
# 13:	learn: 4967.7737738	total: 29.3ms	remaining: 180ms
# 14:	learn: 4886.4254752	total: 31.1ms	remaining: 176ms
# 15:	learn: 4820.9000223	total: 32.6ms	remaining: 171ms
# 16:	learn: 4762.2294236	total: 34.3ms	remaining: 167ms
# 17:	learn: 4713.9096814	total: 36ms	remaining: 164ms
# 18:	learn: 4574.1822567	total: 37.5ms	remaining: 160ms
# 19:	learn: 4527.0905998	total: 39.3ms	remaining: 157ms
# 20:	learn: 4388.2326260	total: 40.8ms	remaining: 153ms
# 21:	learn: 4302.7006632	total: 42.4ms	remaining: 150ms
# 22:	learn: 4239.2824247	total: 43.8ms	remaining: 147ms
# 23:	learn: 4170.6238898	total: 45.7ms	remaining: 145ms
# 24:	learn: 4095.9734587	total: 47.2ms	remaining: 142ms
# 25:	learn: 4017.1650654	total: 48.8ms	remaining: 139ms
# 26:	learn: 3939.9185897	total: 50.5ms	remaining: 137ms
# 27:	learn: 3904.5740118	total: 52.5ms	remaining: 135ms
# 28:	learn: 3858.5956534	total: 54.2ms	remaining: 133ms
# 29:	learn: 3735.5407847	total: 56.2ms	remaining: 131ms
# 30:	learn: 3690.1781287	total: 58.1ms	remaining: 129ms
# 31:	learn: 3643.7943119	total: 60.7ms	remaining: 129ms
# 32:	learn: 3614.3415334	total: 62.8ms	remaining: 127ms
# 33:	learn: 3583.9534606	total: 64.8ms	remaining: 126ms
# 34:	learn: 3578.7906042	total: 67.2ms	remaining: 125ms
# 35:	learn: 3571.8337784	total: 69.1ms	remaining: 123ms
# 36:	learn: 3526.0164725	total: 71ms	remaining: 121ms
# 37:	learn: 3456.2235342	total: 72.9ms	remaining: 119ms
# 38:	learn: 3371.0239467	total: 75ms	remaining: 117ms
# 39:	learn: 3295.9030172	total: 76.8ms	remaining: 115ms
# 40:	learn: 3225.6147816	total: 78.5ms	remaining: 113ms
# 41:	learn: 3162.0363371	total: 80.1ms	remaining: 111ms
# 42:	learn: 3108.3663607	total: 82.2ms	remaining: 109ms
# 43:	learn: 3061.3373444	total: 84ms	remaining: 107ms
# 44:	learn: 3054.7558294	total: 85.4ms	remaining: 104ms
# 45:	learn: 3024.7175511	total: 86.8ms	remaining: 102ms
# 46:	learn: 2997.8070446	total: 88.5ms	remaining: 99.8ms
# 47:	learn: 2981.6509890	total: 90.3ms	remaining: 97.9ms
# 48:	learn: 2979.7177483	total: 92.1ms	remaining: 95.9ms
# 49:	learn: 2940.7336696	total: 93.8ms	remaining: 93.8ms
# 50:	learn: 2902.3614941	total: 95.8ms	remaining: 92.1ms
# 51:	learn: 2878.6196391	total: 97.5ms	remaining: 90ms
# 52:	learn: 2840.6975148	total: 99.4ms	remaining: 88.1ms
# 53:	learn: 2794.9255043	total: 101ms	remaining: 86.1ms
# 54:	learn: 2767.2253798	total: 103ms	remaining: 84ms
# 55:	learn: 2733.0697789	total: 104ms	remaining: 82.1ms
# 56:	learn: 2712.8711790	total: 106ms	remaining: 80.3ms
# 57:	learn: 2702.8304999	total: 107ms	remaining: 77.8ms
# 58:	learn: 2676.0225663	total: 109ms	remaining: 75.8ms
# 59:	learn: 2642.5037165	total: 111ms	remaining: 74.1ms
# 60:	learn: 2596.1748021	total: 113ms	remaining: 72ms
# 61:	learn: 2562.0068468	total: 115ms	remaining: 70.6ms
# 62:	learn: 2543.9288177	total: 117ms	remaining: 68.8ms
# 63:	learn: 2524.6413428	total: 119ms	remaining: 67ms
# 64:	learn: 2498.1018482	total: 121ms	remaining: 65ms
# 65:	learn: 2470.2810645	total: 122ms	remaining: 63ms
# 66:	learn: 2454.7039507	total: 125ms	remaining: 61.3ms
# 67:	learn: 2431.0801858	total: 127ms	remaining: 59.5ms
# 68:	learn: 2394.8625037	total: 128ms	remaining: 57.5ms
# 69:	learn: 2384.4198829	total: 130ms	remaining: 55.5ms
# 70:	learn: 2357.8945628	total: 131ms	remaining: 53.5ms
# 71:	learn: 2349.0960495	total: 133ms	remaining: 51.6ms
# 72:	learn: 2337.0768608	total: 134ms	remaining: 49.5ms
# 73:	learn: 2318.3762780	total: 135ms	remaining: 47.6ms
# 74:	learn: 2293.1055467	total: 137ms	remaining: 45.6ms
# 75:	learn: 2271.7968902	total: 138ms	remaining: 43.6ms
# 76:	learn: 2270.9303520	total: 140ms	remaining: 41.7ms
# 77:	learn: 2259.5723602	total: 141ms	remaining: 39.7ms
# 78:	learn: 2251.0902483	total: 142ms	remaining: 37.8ms
# 79:	learn: 2236.3127011	total: 144ms	remaining: 35.9ms
# 80:	learn: 2231.5787742	total: 145ms	remaining: 34ms
# 81:	learn: 2206.7513651	total: 146ms	remaining: 32.1ms
# 82:	learn: 2184.8700128	total: 148ms	remaining: 30.3ms
# 83:	learn: 2172.3364761	total: 150ms	remaining: 28.5ms
# 84:	learn: 2161.0500624	total: 151ms	remaining: 26.6ms
# 85:	learn: 2132.8021454	total: 152ms	remaining: 24.8ms
# 86:	learn: 2124.7614143	total: 154ms	remaining: 23ms
# 87:	learn: 2094.2581893	total: 156ms	remaining: 21.2ms
# 88:	learn: 2077.1499597	total: 157ms	remaining: 19.4ms
# 89:	learn: 2062.1258047	total: 158ms	remaining: 17.6ms
# 90:	learn: 2029.4112161	total: 160ms	remaining: 15.8ms
# 91:	learn: 2013.5591991	total: 162ms	remaining: 14ms
# 92:	learn: 2002.3733030	total: 163ms	remaining: 12.3ms
# 93:	learn: 1992.2789432	total: 165ms	remaining: 10.5ms
# 94:	learn: 1973.6044885	total: 166ms	remaining: 8.73ms
# 95:	learn: 1955.6661413	total: 167ms	remaining: 6.98ms
# 96:	learn: 1934.9276036	total: 170ms	remaining: 5.26ms
# 97:	learn: 1922.7319773	total: 171ms	remaining: 3.5ms
# 98:	learn: 1915.0524834	total: 173ms	remaining: 1.74ms
# 99:	learn: 1911.2347285	total: 174ms	remaining: 0us
# CatBoostRegressor(loss_function='RMSE', n_estimators=100)

# %% [markdown]
# ### 10 . KNN Regression ---> Neighbour Data Points --->neighbours predictions ---> closer predictions

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
KNN = KNeighborsRegressor(n_neighbors = 5)

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predict = KNN.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 5767.736263736264

# %% [markdown]
# ### 11. Support Vector Machine (SVR) Regressor

# %%
from sklearn.svm import SVR

# %%
SVR = SVR(kernel = 'rbf')

# %%
SVR.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_predict = SVR.predict(x_test)

# %%
mean_absolute_error(y_test,y_predict) ## very huge
# Out:
# 14304.243421712292

# %% [markdown]
# ### 12. Bagging Regressor ---> Ensemble Learning
