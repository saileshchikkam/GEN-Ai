# %% [markdown]
# # Data Gathering Using API

# %%
https://api.themoviedb.org/3/movie/popular?api_key=3dc796da15d378027435a3fe8c3edb84&language=en-US&page=1

# %%
https://api.themoviedb.org/3/movie/now_playing?api_key=3dc796da15d378027435a3fe8c3edb84&language=en-US&page=1

# %% [markdown]
# ## for gathering the data from the web server or data base we use requests library

# %%
import requests

# %%
requests.get('https://api.themoviedb.org/3/movie/popular?api_key=3dc796da15d378027435a3fe8c3edb84&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
url = 'https://api.themoviedb.org/3/movie/popular?api_key=3dc796da15d378027435a3fe8c3edb84&language=en-US&page=1'

# %%
url = 'https://api.themoviedb.org/3/movie/popular?api_key=3dc796da15d378027435a3fe8c3edb84&language=en-US&page=1'

headers = {
    "accept": "application/json",
    "Authorization": "Bearer ee73dd75-e3d9-4cef-846b-947fb01e268a"
}

response = requests.get(url=url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/7iwUUcKURMT7aKfCwMy6YnGtchD.jpg","genre_ids":[878,28,12],"id":969681,"title":"Spider-Man: Brand New Day","original_language":"en","original_title":"Spider-Man: Brand New Day","overview":"Fighting crime full-time as Spider-Man in a world that doesn't remember him—and the pressure of seeing his old friends move on without him—sparks a change in Peter Parker he may not have the power to control. But that transformation might also be the only thing that can stop a shocking new threat to the city and those he loves - a powerful villain no one can even see.","popularity":1453.6083,"poster_path":"/iPOn6DinuVyLY17YM9mKuPofV08.jpg","release_date":"2026-07-29","softcore":false,"video":false,"vote_average":7.9,"vote_count":2071},{"adult":false,"backdrop_path":"/RMXG8myu1aGlNUsRjtxzmpdMK0.jpg","genre_ids":[12,28,14],"id":1368337,"title":"The Odyssey","original_language":"en","original_title":"The Odyssey","overview":"Odysseus, the legendary K
# ...
