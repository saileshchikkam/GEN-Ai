# %% [markdown]
# # Automated Data Cleaning

# %% [markdown]
# #### Types of Missing Data :
#
# #### 1. Missing Compleately at Random (MCAR)
# #### 2. Missing At Random (MAR)
# #### 3. Missing Not At Random (MNAR)

# %%
import pandas as pd

# %%
df = pd.read_csv('unclean_smartwatch_health_data.csv')

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   object
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df['User ID'].isnull().sum()
# Out:
# np.int64(201)

# %%
df = df.drop(columns=['User ID'])

# %%
df.isnull().sum()
# Out:
# Heart Rate (BPM)          400
# Blood Oxygen Level (%)    300
# Step Count                100
# Sleep Duration (hours)    150
# Activity Level            200
# Stress Level              200
# dtype: int64

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(400)

# %%
## 400 ---> 1,2,3 which one
df[df['Heart Rate (BPM)'].isnull()==True]
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 1                  NaN               98.532195    727.601610
# 17                 NaN               96.052853   3488.919508
# 75                 NaN              100.000000   3124.118038
# 105                NaN               98.276558   3039.112276
# 158                NaN               99.478461  11559.663606
# ...                ...                     ...           ...
# 9875               NaN               99.842527   4454.770218
# 9956               NaN              100.000000   3584.236177
# 9971               NaN               99.319841     26.215769
# 9990               NaN              100.000000   3817.269018
# 9998               NaN               98.401058   3364.788855
#
#      Sleep Duration (hours) Activity Level Stress Level
# 1         6.538239375570314  Highly_Active            5
# 17        6.718661172525927     Seddentary            4
# 75        4.229887888280923          Actve            1
# ...

# %%
## drop missing data ----> dropna()

# %%
## Mean/Median Imputation ---> Fill the Missing Data with the Mean or Median of ALL rows of that column

# %%
## While gng with mean value ---> Check for the Outliers

## Age ---> 500(Outliers) ---> 10000 ---> mean ???

## Age ---> Median ---> If you will arrange all values from low to high side ---> Middle value

## Age ---> Mode ---> Most Frequent Age ---> Age

## 1,2,3,...50...100,500

# %%
df['Heart Rate (BPM)'].describe()
# Out:
# count    9600.000000
# mean       76.035462
# std        19.412483
# min        40.000000
# 25%        64.890152
# 50%        75.220601
# 75%        85.198249
# max       296.593970
# Name: Heart Rate (BPM), dtype: float64

# %%
df['Heart Rate (BPM)'].median()
# Out:
# 75.22060125775644

# %%
df['Heart Rate (BPM)']=df['Heart Rate (BPM)'].fillna(df['Heart Rate (BPM)'].median())

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  9700 non-null   float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
## Next Column
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(300)

# %%
df[df['Blood Oxygen Level (%)'].isnull()==True]
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 10          101.914938                     NaN   2987.568640
# 21           68.310104                     NaN   1058.374274
# 133          77.907578                     NaN  15672.467752
# 134          78.227923                     NaN    789.365922
# 187          89.486636                     NaN   2689.849911
# ...                ...                     ...           ...
# 9834         64.803112                     NaN   1647.308449
# 9861         57.617790                     NaN  14269.737149
# 9885         75.281591                     NaN   3852.160740
# 9905         87.693723                     NaN   2364.028205
# 9979         58.797407                     NaN    359.210435
#
#      Sleep Duration (hours) Activity Level Stress Level
# 10        7.541956463173237      Sedentary            9
# 21        6.456918401449286          Actve            3
# 133       9.079469571860296      Sedentary           10
# ...

# %%
## We Should figure out are there any outliers or not
df.describe()
# Out:
#        Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count      10000.000000             9700.000000   9900.000000
# mean          76.002867               97.841581   6985.685885
# std           19.020902                1.732863   6885.809680
# min           40.000000               90.791208      0.910138
# 25%           65.322796               96.662683   2021.039657
# 50%           75.220601               98.010642   4962.534599
# 75%           84.791711               99.376179   9724.902880
# max          296.593970              100.000000  62486.690753

# %%
## No Outliers
df['Blood Oxygen Level (%)']=df['Blood Oxygen Level (%)'].fillna(df['Blood Oxygen Level (%)'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
### Forward Filling or Backward filling ---> Part of Time Series Data

### Forward Filling --->
5
6
7
9
10

### Backward filling
5
6
8
8
9
# Out:
# 9

# %%
df.isnull().sum()
# Out:
# Heart Rate (BPM)            0
# Blood Oxygen Level (%)      0
# Step Count                  0
# Sleep Duration (hours)    150
# Activity Level            200
# Stress Level              200
# dtype: int64

# %%
df[df['Step Count'].isnull() == True]
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)  Step Count  \
# 136          70.593014               97.473981         NaN
# 204          75.220601               98.710637         NaN
# 603          69.084103               99.627473         NaN
# 716          83.258294               98.704757         NaN
# 739          97.506420               97.651407         NaN
# ...                ...                     ...         ...
# 9097         62.072133               96.810967         NaN
# 9121         54.793814               99.670176         NaN
# 9191        101.777396              100.000000         NaN
# 9527         75.220601               94.694312         NaN
# 9565         90.411615               95.009355         NaN
#
#      Sleep Duration (hours) Activity Level Stress Level
# 136       3.439287691081752  Highly_Active            6
# 204       5.756958709255954  Highly_Active            8
# 603       6.358184719715759  Highly_Active            7
# ...

# %%
## Forward Filling
### method ----> ffill or bfill

df['Step Count']=df['Step Count'].fillna(method='ffill')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27748\1947579252.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Step Count']=df['Step Count'].fillna(method='ffill')

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
df['Sleep Duration (hours)'].dtype
# Out:
# dtype('O')

# %%
## not completly objects but some values are of object but other float
df.head()
# Out:
#    Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0         58.939776               98.809650   5450.390578
# 1         75.220601               98.532195    727.601610
# 2        247.803052               97.052954   2826.521994
# 3         40.000000               96.894213  13797.338044
# 4         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df[df['Sleep Duration (hours)'] == "ERROR"].shape
## 247 rows 😯
# Out:
# (247, 6)

# %%
## should we remove all rows of errors NO
## ERROR values to missing values

## First Object dtype ---> Numeric ---> pandas we use
## the function is to_numeric() in pandas library

# %%
df['Sleep Duration (hours)'] = pd.to_numeric(df['Sleep Duration (hours)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "ERROR"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df['Sleep Duration (hours)'] = pd.to_numeric(df['Sleep Duration (hours)'])
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
# ...

# %%
df['Sleep Duration (hours)'] = pd.to_numeric(df['Sleep Duration (hours)'],errors = 'coerce')

# %%
## ERRORS ---> NaN values 😊

# %%
df[df['Sleep Duration (hours)']=='ERROR']
## No Errors😁
# Out:
# Empty DataFrame
# Columns: [Heart Rate (BPM), Blood Oxygen Level (%), Step Count, Sleep Duration (hours), Activity Level, Stress Level]
# Index: []

# %%
df['Sleep Duration (hours)'].dtype
# Out:
# dtype('float64')

# %%
df['Sleep Duration (hours)'].mean()
# Out:
# np.float64(6.505462918406444)

# %%
df['Sleep Duration (hours)'].median()
# Out:
# 6.503308362112644

# %%
df['Sleep Duration (hours)'] = df['Sleep Duration (hours)'].fillna(df['Sleep Duration (hours)'].mean())

# %%
df['Sleep Duration (hours)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0         58.939776               98.809650   5450.390578
# 1         75.220601               98.532195    727.601610
# 2        247.803052               97.052954   2826.521994
# 3         40.000000               96.894213  13797.338044
# 4         61.950165               98.583797  15679.067648
#
#    Sleep Duration (hours) Activity Level Stress Level
# 0                7.167236  Highly Active            1
# 1                6.538239  Highly_Active            5
# 2                6.505463  Highly Active            5
# 3                7.367790          Actve            3
# 4                6.505463  Highly_Active            6

# %%
## For Categorical Columns ---> Mode Frequently Repeating value in your column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
## Next Column
df['Activity Level'].isnull().sum()
# Out:
# np.int64(200)

# %%
df['Activity Level'].mode()
# Out:
# 0    Seddentary
# Name: Activity Level, dtype: object

# %%
df['Activity Level'] = df['Activity Level'].fillna('Seddentary')

# %%
df['Activity Level']
# Out:
# 0       Highly Active
# 1       Highly_Active
# 2       Highly Active
# 3               Actve
# 4       Highly_Active
#             ...
# 9995           Active
# 9996        Sedentary
# 9997        Sedentary
# 9998           Active
# 9999            Actve
# Name: Activity Level, Length: 10000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(200)

# %%
## Constant Imputation ---> When you want to fill missing values with a constant value like 'unknown' or 0

# %%
df['Stress Level'].value_counts()
# Out:
# Stress Level
# 2            1007
# 7            1006
# 6            1001
# 3             995
# 1             984
# 9             976
# 4             966
# 10            954
# 5             945
# 8             917
# Very High      49
# Name: count, dtype: int64

# %%
df['Stress Level'] = df['Stress Level'].fillna(5)

# %%
df['Stress Level']
# Out:
# 0       1
# 1       5
# 2       5
# 3       3
# 4       6
#        ..
# 9995    7
# 9996    2
# 9997    4
# 9998    8
# 9999    5
# Name: Stress Level, Length: 10000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              10000 non-null  float64
#  3   Sleep Duration (hours)  10000 non-null  float64
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            10000 non-null  object
# dtypes: float64(4), object(2)
# memory usage: 468.9+ KB

# %% [markdown]
# ### All missing values are replaced and fill
#
#
# ### this ia all manually but we can automate all these using simple imupter

# %%
### Automated Data Cleaning

# %%
df = pd.read_csv('unclean_smartwatch_health_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9799 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9700 non-null   float64
#  3   Step Count              9900 non-null   float64
#  4   Sleep Duration (hours)  9850 non-null   object
#  5   Activity Level          9800 non-null   object
#  6   Stress Level            9800 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 547.0+ KB

# %%
df = df.drop(columns=['User ID'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        9600 non-null   float64
#  1   Blood Oxygen Level (%)  9700 non-null   float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = 'median')

# %%
df['Heart Rate (BPM)'] = imputer.fit_transform(df['Heart Rate (BPM)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 df['Heart Rate (BPM)'] = imputer.fit_transform(df['Heart Rate (BPM)'])
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
## double paranthesis and ravel() ---> function
df['Heart Rate (BPM)'] = imputer.fit_transform(df[['Heart Rate (BPM)']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  9700 non-null   float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count      10000.000000             9700.000000   9900.000000
# mean          76.002867               97.841581   6985.685885
# std           19.020902                1.732863   6885.809680
# min           40.000000               90.791208      0.910138
# 25%           65.322796               96.662683   2021.039657
# 50%           75.220601               98.010642   4962.534599
# 75%           84.791711               99.376179   9724.902880
# max          296.593970              100.000000  62486.690753

# %%
imputer = SimpleImputer(strategy = 'mean')

# %%
df['Blood Oxygen Level (%)'] = imputer.fit_transform(df[['Blood Oxygen Level (%)']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          9800 non-null   object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
df['Activity Level'] = imputer.fit_transform(df[['Activity Level']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            9800 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB

# %%
imputer = SimpleImputer(strategy='constant',fill_value=5)

# %%
df['Stress Level'] = imputer.fit_transform(df[['Stress Level']]).ravel()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Heart Rate (BPM)        10000 non-null  float64
#  1   Blood Oxygen Level (%)  10000 non-null  float64
#  2   Step Count              9900 non-null   float64
#  3   Sleep Duration (hours)  9850 non-null   object
#  4   Activity Level          10000 non-null  object
#  5   Stress Level            10000 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 468.9+ KB
