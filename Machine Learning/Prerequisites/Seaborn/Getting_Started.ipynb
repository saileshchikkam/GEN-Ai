# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Numpy, Pandas, Matplotlib, Plotly, Seaborn ---> ALL of these libraries will be required over here

# %%
pip install seaborn

# %%
pip install plotly
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.9 MB 1.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.9 MB 1.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.9 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.9 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.9 MB 959.1 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.9 MB 959.1 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 962.8 kB/s eta 0:00:09
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Relational Plot
#
# ### It is beign used to figure out the relation between 2 or more numerical variables
#
# ### It hepls us out to figure out how the changes in one numerical column will change or effects the other numerical column
#
# ### It used for ====> Bivariante Analysis
# ###             ====> Numerical - Numerical
#
# ### Line Plot --- > Line Plot is being used for Time Series Analysis (wrt Time how one quantity is going to vary ) --- > X axis --- > Time
#
# ### Scatter PLot ---> Scatter PLot show how 2 numerical variables or are corelated that means if one numerical column will vary then how it will affect the other numerical column
#
# #### Correlation btw 2 Numerical Coulmn
# #### Study Hours <<---->> Exam Score Correlation

# %% [markdown]
# ## Axis Level Functions
# #### *Line Plot --->  sns.lineplot()
# #### lineplot() ---> data ---> dataframe value from where we will be selecting the columns for analysis
#
# #### x---> 'Column_name' ---> that you want to keep on the x axis and this  column name will directly behave as like the x-label for us
#
# #### y---> 'column_name' (similarly aas like the x axis)
#
# #### *Scatter Plot ----> sns.scatterplot()
# ==============================================================================
# ## FigureLevel Function
# ##### relplot() ---> it is figure level function and capable of plotting both lineplot aand scatterpplot based on the Kind Parameter
#
# #### kind = 'line' ---> line Plot
# #### kind = 'scatter' ---> scatterplot

# %%
df_dep = pd.read_csv('Student Depression Dataset.csv')

# %%
sales = pd.read_csv('Chocolate Sales.csv')

# %%
df_dep.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %% [markdown]
# ## Axis Level Function ----> lineplot()

# %%
sns.lineplot(data = df_dep, x='Age',y='CGPA')
# Out:
# <Axes: xlabel='Age', ylabel='CGPA'>
