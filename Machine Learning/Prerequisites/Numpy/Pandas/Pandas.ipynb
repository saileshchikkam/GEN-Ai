# %% [markdown]
# # Pandas

# %% [markdown]
# ## Pandas is a Powerful Library used for Data Manipulation and Analysis . It helps us to work with data in Tabular Format , just like how we deal with data and spreadsheet in excel or database .

# %% [markdown]
# ## Pandas provides functionalities and attributes to clean organize and analyze large amounts of data

# %% [markdown]
# 1. Easy To Use -- > Works like Excel inside
# Python
# 2. Fast --- > Handles Large Data Faster than
# Manual Methods
# 3. Clean Data --- > helps clean, filter and
# transform messy data
# 4. Integrates well -- > Matplotlib, Seaborn
# 5. Ideal For ML and AI -- >it is ideal for data
# science
