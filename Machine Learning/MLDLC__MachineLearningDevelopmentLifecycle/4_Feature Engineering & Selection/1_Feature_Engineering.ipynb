# %% [markdown]
# ## Feature Engineering ---> It is the process of creating New and better features for our model from which we can have better insights or we can make better prediction model

# %% [markdown]
# ### New Features(Columns) Will be Created here

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv("Titanic-Dataset.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
test = pd.read_csv('titanic.csv')

# %%
test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df = pd.concat([titanic,test])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (1309, 12)

# %%
df['Family-Size'] = df['SibSp'] + df['Parch'] + 1 ## name is for the passenger name right

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family-Size
# 0      0         A/5 21171   7.2500   NaN        S            2
# 1      0          PC 17599  71.2833   C85        C            2
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1
# ...

# %%
sns.barplot(data=df,x='Family-Size',y='Survived')
# Out:
# <Axes: xlabel='Family-Size', ylabel='Survived'>

# %%
def family_type(num):
    if num >=1 and num<=3:
        return 'small family'
    elif num >=3 and num <= 5:
        return 'medium family'
    else:
        return 'large family'

# %%
df['Family-Type'] = df['Family-Size'].apply(family_type)

# %%
df.head() ## new column added family-type
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family-Size   Family-Type
# 0      0         A/5 21171   7.2500   NaN        S            2  small family
# 1      0          PC 17599  71.2833   C85        C            2  small family
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1  small family
# ...

# %%
df['Family-Type'].value_counts()
# Out:
# Family-Type
# small family     1184
# medium family      65
# large family       60
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x='Family-Type',y='Survived')
# Out:
# <Axes: xlabel='Family-Type', ylabel='Survived'>

# %%
pd.crosstab(df['Family-Type'],df['Survived'])
# Out:
# Survived         0    1
# Family-Type
# large family    47   13
# medium family   29   36
# small family   739  445

# %%
sns.heatmap(pd.crosstab(df['Family-Type'],df['Survived'],normalize=True)*100)
# Out:
# <Axes: xlabel='Survived', ylabel='Family-Type'>

# %%
## Next Column
df[df['SibSp'] == 5]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 59            60         0       3  Goodwin, Master. William Frederick
# 71            72         0       3          Goodwin, Miss. Lillian Amy
# 386          387         0       3     Goodwin, Master. Sidney Leonard
# 480          481         0       3      Goodwin, Master. Harold Victor
# 683          684         0       3         Goodwin, Mr. Charles Edward
# 140         1032         1       3         Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked  Family-Size  \
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S            8
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S            8
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S            8
# 480    male   9.0      5      2  CA 2144  46.9   NaN        S            8
# 683    male  14.0      5      2  CA 2144  46.9   NaN        S            8
# ...

# %%
df[df['Ticket'] == 'CA 2144'] ## Goodwin family
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60         0       3       Goodwin, Master. William Frederick
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 386          387         0       3          Goodwin, Master. Sidney Leonard
# 480          481         0       3           Goodwin, Master. Harold Victor
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684         0       3              Goodwin, Mr. Charles Edward
# 139         1031         0       3           Goodwin, Mr. Charles Frederick
# 140         1032         1       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked  Family-Size  \
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S            8
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S            8
# ...

# %%
df['Individual Fare'] = df['Fare']/df['Family-Size']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family-Size   Family-Type  \
# 0      0         A/5 21171   7.2500   NaN        S            2  small family
# 1      0          PC 17599  71.2833   C85        C            2  small family
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1  small family
# ...

# %%
df[df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60         0       3       Goodwin, Master. William Frederick
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 386          387         0       3          Goodwin, Master. Sidney Leonard
# 480          481         0       3           Goodwin, Master. Harold Victor
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684         0       3              Goodwin, Mr. Charles Edward
# 139         1031         0       3           Goodwin, Mr. Charles Frederick
# 140         1032         1       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked  Family-Size  \
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S            8
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S            8
# ...

# %%
df[df['Ticket'] == 'CA 2144'][['Name','Family-Size','Fare','Individual Fare']]
# Out:
#                                         Name  Family-Size  Fare  \
# 59        Goodwin, Master. William Frederick            8  46.9
# 71                Goodwin, Miss. Lillian Amy            8  46.9
# 386          Goodwin, Master. Sidney Leonard            8  46.9
# 480           Goodwin, Master. Harold Victor            8  46.9
# 678  Goodwin, Mrs. Frederick (Augusta Tyler)            8  46.9
# 683              Goodwin, Mr. Charles Edward            8  46.9
# 139           Goodwin, Mr. Charles Frederick            8  46.9
# 140              Goodwin, Miss. Jessie Allis            8  46.9
#
#      Individual Fare
# 59            5.8625
# 71            5.8625
# 386           5.8625
# 480           5.8625
# 678           5.8625
# 683           5.8625
# 139           5.8625
# 140           5.8625

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 413                                   Spector, Mr. Woolf
# 414                         Oliva y Ocana, Dona. Fermina
# 415                         Saether, Mr. Simon Sivertsen
# 416                                  Ware, Mr. Frederick
# 417                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %% [markdown]
# #### .strip() ---> for extra spaces
# #### .split() ---> to split

# %%
df['Name Prefix'] = df['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family-Size   Family-Type  \
# 0      0         A/5 21171   7.2500   NaN        S            2  small family
# 1      0          PC 17599  71.2833   C85        C            2  small family
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1  small family
# ...

# %%
df['Name Prefix'].value_counts()
# Out:
# Name Prefix
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Major             2
# Mlle              2
# Ms                2
# Mme               1
# Don               1
# Sir               1
# Lady              1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: count, dtype: int64
