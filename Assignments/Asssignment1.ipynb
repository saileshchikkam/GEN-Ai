# %% [markdown]
# # Task 1

# %%
products = ["Mobile","Handbags","Guns","Clothes","Kitchen ware"]

sample_products = ("Apple iphone 17 pro",170000,"Mobile")

print(products[1])
print(products[len(products)-1])

products.append("Baloons")
products.append("Keyboards")

print(products)

sample_products_list = []

for i in sample_products:
    sample_products_list.append(i)

change = 150000
sample_products_list[1] = change
sample_products = (sample_products_list)
print(sample_products)
# Out:
# Handbags
# Kitchen ware
# ['Mobile', 'Handbags', 'Guns', 'Clothes', 'Kitchen ware', 'Baloons', 'Keyboards']
# ['Apple iphone 17 pro', 150000, 'Mobile']

# %% [markdown]
# # Task 2

# %%
categories_set = {"Mobile","Clothes"}
categories_set.add("Bikes")
print(categories_set)

categories_set.add("Mobile")
print(categories_set)
print("Again here mobile not added because duplicates are not allowed in the sets")

product = input("Enter the product category to check whether it exists in the set or not")

if product in categories_set:
    print(f"{product} exists in categories_set")
else:
    print(f"{product} doesn't exists")

count = 0
for i in categories_set:
    count += 1
    
print(f"total number of unique categories in set are {count}")
# Out:
# {'Bikes', 'Clothes', 'Mobile'}
# {'Bikes', 'Clothes', 'Mobile'}
# Again here mobile not added because duplicates are not allowed in the sets
# shampoo doesn't exists
# total number of unique categories in set are 3

# %% [markdown]
# # Task 3

# %%
price_dict = {'iphone' : 150000 ,
              'shampoo' : 200,
              'keychain' : 150,
              'baloons' : 20,
              'Chocolates' : 300,
              'hats' : 50
              }

print(price_dict)

#deleted
del price_dict["hats"]
print(price_dict)

#added
price_dict["Earbuds"] = 2000
print(price_dict)

# updating price of baloons
price_dict["baloons"] = 30
print(price_dict)

count = 0
sum = 0

for i in price_dict.values():
    sum += i
    count+=1

average = sum / count
print(average)
# Out:
# {'iphone': 150000, 'shampoo': 200, 'keychain': 150, 'baloons': 20, 'Chocolates': 300, 'hats': 50}
# {'iphone': 150000, 'shampoo': 200, 'keychain': 150, 'baloons': 20, 'Chocolates': 300}
# {'iphone': 150000, 'shampoo': 200, 'keychain': 150, 'baloons': 20, 'Chocolates': 300, 'Earbuds': 2000}
# {'iphone': 150000, 'shampoo': 200, 'keychain': 150, 'baloons': 30, 'Chocolates': 300, 'Earbuds': 2000}
# 25446.666666666668

# %% [markdown]
# ## Task 4

# %%
products = [
    "Laptop",
    "Mouse",
    "Keyboard",
    "Mobile",
    "Monitor",
    "Printer"
]

price_dict = {
    "Laptop": 60000,
    "Mouse": 500,
    "Keyboard": 1200,
    "Mobile": 25000,
    "Monitor": 15000,
    "Printer": 8000
}

category_dict = {
    "Laptop": "Electronics",
    "Mouse": "Accessories",
    "Keyboard": "Accessories",
    "Mobile": "Electronics",
    "Monitor": "Electronics",
    "Printer": "Accessories"
}

# Step 1: Create catalog list
catalog = []

for product in products:
    catalog.append((product, price_dict[product], category_dict[product]))

print("Catalog:")
for item in catalog:
    print(item)

# Step 2: Create category_to_products dictionary
category_to_products = {}

for product in products:
    category = category_dict[product]

    if category not in category_to_products:
        category_to_products[category] = []

    category_to_products[category].append(product)

print("\nCategory to Products:")
for category in category_to_products:
    print(category, ":", category_to_products[category])

# Step 3: Find category with maximum products
max_category = ""
max_count = 0

for category in category_to_products:
    if len(category_to_products[category]) > max_count:
        max_count = len(category_to_products[category])
        max_category = category

print("\nCategory with Maximum Products:", max_category)

print("Products in", max_category + ":")
for product in category_to_products[max_category]:
    print(product)
# Out:
# Catalog:
# ('Laptop', 60000, 'Electronics')
# ('Mouse', 500, 'Accessories')
# ('Keyboard', 1200, 'Accessories')
# ('Mobile', 25000, 'Electronics')
# ('Monitor', 15000, 'Electronics')
# ('Printer', 8000, 'Accessories')
#
# Category to Products:
# Electronics : ['Laptop', 'Mobile', 'Monitor']
# Accessories : ['Mouse', 'Keyboard', 'Printer']
#
# Category with Maximum Products: Electronics
# Products in Electronics:
# Laptop
# Mobile
# Monitor
