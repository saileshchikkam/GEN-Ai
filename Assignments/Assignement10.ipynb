# %% [markdown]
# # Task 1

# %%
import pandas as pd

# %%
marks = pd.Series([78,85,90,66,72])

# %%
marks
# Out:
# 0    78
# 1    85
# 2    90
# 3    66
# 4    72
# dtype: int64

# %%
marks.value_counts()
# Out:
# 78    1
# 85    1
# 90    1
# 66    1
# 72    1
# Name: count, dtype: int64

# %%
marks.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
marks.dtype
# Out:
# dtype('int64')

# %%
marks.head(1)
# Out:
# 0    78
# dtype: int64

# %%
marks.tail(2)
# Out:
# 3    66
# 4    72
# dtype: int64

# %% [markdown]
# # Task 2

# %%
marks
# Out:
# 0    78
# 1    85
# 2    90
# 3    66
# 4    72
# dtype: int64

# %%
marks=pd.Series(marks + 5)
marks
# Out:
# 0    83
# 1    90
# 2    95
# 3    71
# 4    77
# dtype: int64

# %%
marks - 2
# Out:
# 0    81
# 1    88
# 2    93
# 3    69
# 4    75
# dtype: int64

# %%
marks * 1.05
# Out:
# 0    87.15
# 1    94.50
# 2    99.75
# 3    74.55
# 4    80.85
# dtype: float64

# %%
marks / 2
# Out:
# 0    41.5
# 1    45.0
# 2    47.5
# 3    35.5
# 4    38.5
# dtype: float64

# %% [markdown]
# # Task 3

# %%
marks
# Out:
# 0    83
# 1    90
# 2    95
# 3    71
# 4    77
# dtype: int64

# %%
print(marks.max())
# Out:
# 95

# %%
print(marks.min())
# Out:
# 71

# %%
print(marks.sum())
# Out:
# 416

# %%
print(marks.mean())
# Out:
# 83.2

# %%
count = 0
for i in marks:
    if(i >= 70):
        count += 1
print(count)
# Out:
# 5

# %% [markdown]
# # Task 4

# %%
students = pd.DataFrame({'Name' : ['Amit','Neha','Rahul','Sneha','Pooja'],
                         'Marks': [78,85,90,66,72],
                         'Subject': ['Math','Math','Science','Science','Math']})

# %%
students
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
students.head(3)
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science

# %%
students.tail(2)
# Out:
#     Name  Marks  Subject
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
students.shape
# Out:
# (5, 3)

# %%
students.columns
# Out:
# Index(['Name', 'Marks', 'Subject'], dtype='str')

# %% [markdown]
# # Task 5

# %%
students.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      str
#  1   Marks    5 non-null      int64
#  2   Subject  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 301.0 bytes

# %%
students.describe()
# Out:
#            Marks
# count   5.000000
# mean   78.200000
# std     9.654015
# min    66.000000
# 25%    72.000000
# 50%    78.000000
# 75%    85.000000
# max    90.000000

# %%
students.head()
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
students.tail()
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
students
# Out:
#     Name  Marks  Subject
# 0   Amit     78     Math
# 1   Neha     85     Math
# 2  Rahul     90  Science
# 3  Sneha     66  Science
# 4  Pooja     72     Math

# %%
students = students['Marks'].sort_values(ascending=False)

# %%
students
# Out:
# 2    90
# 1    85
# 0    78
# 4    72
# 3    66
# Name: Marks, dtype: int64

# %%
students=students.reset_index()

# %%
students
# Out:
#    index  Marks
# 0      2     90
# 1      1     85
# 2      0     78
# 3      4     72
# 4      3     66

# %% [markdown]
# # Task 6
